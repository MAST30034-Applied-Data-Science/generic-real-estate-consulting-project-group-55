# %%
import pandas as pd
import operator
from sklearn.linear_model import LinearRegression  
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Data Proprecessing

# %% [markdown]
# ## Rent Data

# %%
post = pd.read_csv("../data/raw/postcode_info.csv")
df = pd.DataFrame()

# %%
rent_data = pd.read_excel("https://www.dffh.vic.gov.au/sites/default/files/documents/202209/Moving%20annual%20rent%20by%20suburb%20-%20June%20quarter%202022.xlsx", sheet_name='All properties')
rent = rent_data.drop(index= list(rent_data[rent_data['Unnamed: 1'] == 'Group Total'].index))
rent_data = rent_data.loc[2:]
rent_data.drop(['Moving annual median rent by suburb'],axis=1,inplace=True)
rent_data = rent_data.loc[:,::2]
rent_data.rename(columns={'Unnamed: 1':'suburb'}, inplace = True)
rent_data.head()
# Out:
#                                   suburb Unnamed: 3 Unnamed: 5 Unnamed: 7  \
# 2  Albert Park-Middle Park-West St Kilda        260        260        270
# 3                               Armadale        200        200        205
# 4                          Carlton North        260        260        265
# 5                      Carlton-Parkville        260        260        260
# 6                        CBD-St Kilda Rd        320        320        320
#
#   Unnamed: 9 Unnamed: 11 Unnamed: 13 Unnamed: 15 Unnamed: 17 Unnamed: 19  ...  \
# 2        275         275         280         280         290         300  ...
# 3        210         215         220         225         230         233  ...
# 4        270         270         275         280         280         290  ...
# 5        260         260         260         265         270         270  ...
# 6        320         320         320         320         320         320  ...
#
#   Unnamed: 163 Unnamed: 165 Unnamed: 167 Unnamed: 169 Unnamed: 171  \
# 2          600          580          550          550          500
# 3          500          500          500          495          450
# 4          585          590          590          590          580
# 5          404          400          400          395          350
# 6          510          495          460          420          380
#
#   Unnamed: 173 Unnamed: 175 Unnamed: 177 Unnamed: 179 Unnamed: 181
# 2          500          500          495          500          520
# 3          440          425          420          430          450
# 4          575          575          580          580          595
# 5          340          330          320          310          319
# 6          369          350          350          364          390
#
# [5 rows x 91 columns]

# %%
#Preprocess suburb
data_suburb = pd.DataFrame()
sublist = []
for i in rent_data["suburb"]:
    index = rent_data[rent_data.suburb == i].index.tolist()[0]
    if operator.contains(i, "-"):
        j = i.split("-")
        for sub in j:
            sublist.append(sub)
            series = pd.DataFrame(rent_data[index-2:index-1])
            data_suburb = pd.concat([data_suburb, series])
    else:
        sublist.append(i)
        series = pd.DataFrame(rent_data[index-2:index-1])
        data_suburb = pd.concat([data_suburb, series])

data_suburb.insert(0, "suburb new", sublist)
data_suburb.drop(data_suburb.columns[1:2],axis=1,inplace=True)
name = ['suburb']
for i in list(range(2,181,2)):
    name.append(rent[rent.columns.values.tolist()[i]][:1].tolist()[0])
data_suburb.columns = name
data_suburb['postcode'] = ''
df = data_suburb.reset_index(drop=True)

# %%
#remove group total
for i in range(len(df)):
    if post[(post['Locality'] == str.upper(df['suburb'][i]))]['Postcode'].to_list() == []:
        df.loc[i,'postcode'] = 0
    else:
        df.loc[i,'postcode'] = post[(post['Locality'] == str.upper(df['suburb'][i])) & (post['State'] == 'VIC')]['Postcode'].to_list()[0]
df=df.drop(df[df['suburb'] == 'Group Total'].index)

# %%
#check which suburb cannot be Identified
df[df['postcode'] == 0]
# Out:
#              suburb Mar 2000 Jun 2000 Sep 2000 Dec 2000 Mar 2001 Jun 2001  \
# 2     West St Kilda      260      260      270      275      275      280
# 7               CBD      320      320      320      320      320      320
# 8       St Kilda Rd      320      320      320      320      320      320
# 13    East St Kilda      180      180      180      180      185      190
# 51    East Hawthorn      200      201      210      215      220      230
# 107  East Brunswick      190      210      210      230      230      240
# 120  West Brunswick      140      141      145      150      150      153
# 153    Yarra Ranges      150      150      155      155      160      160
# 171        Mt Eliza      170      175      180      180      185      190
# 173       Mt Martha      170      175      180      180      185      190
# 181        Newcombe      135      140      140      140      145      145
# 198    Bendigo East      140      140      140      145      145      145
# 223     Wanagaratta      125      125      130      130      130      130
#
#     Sep 2001 Dec 2001 Mar 2002  ... Jun 2020 Sep 2020 Dec 2020 Mar 2021  \
# 2        280      290      300  ...      580      550      550      500
# 7        320      320      320  ...      495      460      420      380
# 8        320      320      320  ...      495      460      420      380
# 13       195      195      200  ...      425      420      410      395
# 51       235      235      230  ...      440      438      420      400
# 107      240      240      250  ...      450      450      425      420
# 120      160      165      170  ...      400      390      380      380
# 153      165      165      165  ...      400      400      400      400
# 171      190      195      200  ...      485      496      508      520
# 173      190      195      200  ...      485      496      508      520
# 181      145      150      150  ...      350      350      360      360
# 198      150      150      155  ...      320      320      320      330
# 223      130      135      135  ...      300      300      308      320
#
#     Jun 2021 Sep 2021 Dec 2021 Mar 2022 Jun 2022 postcode
# 2        500      500      495      500      520        0
# 7        369      350      350      364      390        0
# 8        369      350      350      364      390        0
# 13       385      380      380      380      390        0
# 51       400      390      380      390      400        0
# 107      410      400      400      400      420        0
# 120      360      350      350      350      360        0
# 153      415      420      425      435      450        0
# 171      545      550      570      590      600        0
# 173      545      550      570      590      600        0
# 181      370      375      380      395      400        0
# 198      340      350      360      370      375        0
# 223      330      350      360      370      380        0
#
# [13 rows x 92 columns]

# %%
#look up suburb from google
df.loc[2,'postcode'] = 3182
df.loc[7,'postcode'] = 3000
df.loc[8,'postcode'] = 3004
df.loc[13,'postcode'] = 3183
df.loc[51,'postcode'] = 3123
df.loc[107,'postcode'] = 3057
df.loc[120,'postcode'] = 3055
df.loc[153,'postcode'] = 3160
df.loc[171,'postcode'] = 3930
df.loc[173,'postcode'] = 3934
df.loc[181,'postcode'] = 3219
df.loc[198,'postcode'] = 3550
df.loc[223,'postcode'] = 3677

# %%
df_past = df.drop(df.columns[1:57], axis=1)
for i in range(1, len(df_past.columns)-2, 4):
    df_past[df_past.columns[i][-4:]] = df_past[[df_past.columns[i], df_past.columns[i+1], df_past.columns[i+2], df_past.columns[i+3]]].mean(axis=1)
    if i  == 33:
        df_past[df_past.columns[i][-4:]] = df_past[[df_past.columns[i], df_past.columns[i+1]]].mean(axis=1)
df_past.head()
# Out:
#           suburb Mar 2014 Jun 2014 Sep 2014 Dec 2014 Mar 2015 Jun 2015  \
# 0    Albert Park      460      470      480      480      480      495
# 1    Middle Park      460      470      480      480      480      495
# 2  West St Kilda      460      470      480      480      480      495
# 3       Armadale      390      395      390      400      400      399
# 4  Carlton North      510      510      520      520      530      530
#
#   Sep 2015 Dec 2015 Mar 2016  ... postcode    2014    2015   2016    2017  \
# 0      495      500      520  ...     3206  472.50  492.50  515.0  527.75
# 1      495      500      520  ...     3206  472.50  492.50  515.0  527.75
# 2      495      500      520  ...     3182  472.50  492.50  515.0  527.75
# 3      400      400      400  ...     3143  393.75  399.75  402.5  445.00
# 4      530      530      530  ...     3054  515.00  530.00  527.5  545.00
#
#      2018    2019    2020    2021   2022
# 0  562.50  569.25  570.00  498.75  510.0
# 1  562.50  569.25  570.00  498.75  510.0
# 2  562.50  569.25  570.00  498.75  510.0
# 3  487.50  481.25  498.75  433.75  440.0
# 4  566.25  579.25  588.75  577.50  587.5
#
# [5 rows x 45 columns]

# %%
#get the rent price from 2014-2022
rent_past = df_past.drop(df_past.columns[1:35], axis=1)
rent_past.head()
# Out:
#           suburb postcode    2014    2015   2016    2017    2018    2019  \
# 0    Albert Park     3206  472.50  492.50  515.0  527.75  562.50  569.25
# 1    Middle Park     3206  472.50  492.50  515.0  527.75  562.50  569.25
# 2  West St Kilda     3182  472.50  492.50  515.0  527.75  562.50  569.25
# 3       Armadale     3143  393.75  399.75  402.5  445.00  487.50  481.25
# 4  Carlton North     3054  515.00  530.00  527.5  545.00  566.25  579.25
#
#      2020    2021   2022
# 0  570.00  498.75  510.0
# 1  570.00  498.75  510.0
# 2  570.00  498.75  510.0
# 3  498.75  433.75  440.0
# 4  588.75  577.50  587.5

# %% [markdown]
# ## Population & Income

# %% [markdown]
# ### We use the population density and weekly income as features

# %%
pop = pd.read_csv("../data/raw/population_postcode.csv", index_col=0)
income = pd.read_csv("../data/raw/VIC_yearly_income_poa.csv", index_col=0)

# %%
#get the past income
income_past = income.drop(list(income.columns)[1:2],axis=1)
income_past = income_past.drop(list(income.columns)[11:],axis=1)
income_past = income_past.rename(columns={'Postcode':'postcode'})
income_past
# Out:
#      postcode  Median weekly income in 2014  Median weekly income in 2015  \
# 0        3000                        628.79                        600.81
# 1        3001                        628.79                        600.81
# 2        8001                        628.79                        600.81
# 3        8003                        628.79                        600.81
# 4        8006                        628.79                        600.81
# ..        ...                           ...                           ...
# 711      3991                        698.38                        695.37
# 712      3992                        698.38                        695.37
# 713      3995                        698.38                        695.37
# 714      3996                        698.38                        695.37
# 715      8008                       1278.23                       1268.75
#
#      Median weekly income in 2016  Median weekly income in 2017  \
# 0                          539.77                        553.96
# 1                          539.77                        553.96
# 2                          539.77                        553.96
# 3                          539.77                        553.96
# 4                          539.77                        553.96
# ..                            ...                           ...
# 711                        701.85                        731.92
# 712                        701.85                        731.92
# 713                        701.85                        731.92
# 714                        701.85                        731.92
# 715                       1256.35                       1317.54
#
#      Median weekly income in 2018  Median weekly income in 2019  \
# 0                          577.38                        566.20
# 1                          577.38                        566.20
# 2                          577.38                        566.20
# 3                          577.38                        566.20
# 4                          577.38                        566.20
# ..                            ...                           ...
# 711                        767.00                        785.36
# 712                        767.00                        785.36
# 713                        767.00                        785.36
# 714                        767.00                        785.36
# 715                       1354.83                       1375.09
#
#      Median weekly income in 2020  Median weekly income in 2021  \
# 0                          555.22                        544.46
# 1                          555.22                        544.46
# 2                          555.22                        544.46
# 3                          555.22                        544.46
# 4                          555.22                        544.46
# ..                            ...                           ...
# 711                        804.17                        823.42
# 712                        804.17                        823.42
# 713                        804.17                        823.42
# 714                        804.17                        823.42
# 715                       1395.65                       1416.52
#
#      Median weekly income in 2022
# 0                          533.91
# 1                          533.91
# 2                          533.91
# 3                          533.91
# 4                          533.91
# ..                            ...
# 711                        843.14
# 712                        843.14
# 713                        843.14
# 714                        843.14
# 715                       1437.70
#
# [716 rows x 10 columns]

# %%
result = pd.merge(rent_past, income_past, how='left', on=['postcode'])
result
# Out:
#             suburb postcode    2014    2015    2016    2017    2018    2019  \
# 0      Albert Park     3206  472.50  492.50  515.00  527.75  562.50  569.25
# 1      Middle Park     3206  472.50  492.50  515.00  527.75  562.50  569.25
# 2    West St Kilda     3182  472.50  492.50  515.00  527.75  562.50  569.25
# 3         Armadale     3143  393.75  399.75  402.50  445.00  487.50  481.25
# 4    Carlton North     3054  515.00  530.00  527.50  545.00  566.25  579.25
# ..             ...      ...     ...     ...     ...     ...     ...     ...
# 210      Traralgon     3844  263.75  270.00  270.00  276.25  278.75  287.50
# 211    Wanagaratta     3677  247.50  250.00  260.00  266.25  274.25  287.50
# 212       Warragul     3820  272.75  280.00  293.75  305.00  323.75  347.00
# 213    Warrnambool     3280  280.00  285.00  288.75  290.00  300.00  322.50
# 214        Wodonga     3689  280.00  287.50  290.00  298.75  302.50  318.75
#
#        2020    2021   2022  Median weekly income in 2014  \
# 0    570.00  498.75  510.0                       1249.52
# 1    570.00  498.75  510.0                       1249.52
# 2    570.00  498.75  510.0                       1012.58
# 3    498.75  433.75  440.0                       1194.02
# 4    588.75  577.50  587.5                       1032.40
# ..      ...     ...    ...                           ...
# 210  307.50  345.00  370.0                        718.02
# 211  299.50  340.00  375.0                        801.48
# 212  360.00  383.75  400.0                        814.42
# 213  342.50  365.00  400.0                        819.90
# 214  330.00  355.00  385.0                        896.35
#
#      Median weekly income in 2015  Median weekly income in 2016  \
# 0                         1300.52                       1272.31
# 1                         1300.52                       1272.31
# 2                         1030.04                       1020.50
# 3                         1234.02                       1232.21
# 4                         1046.38                       1055.31
# ..                            ...                           ...
# 210                        699.37                        680.54
# 211                        824.62                        845.62
# 212                        820.77                        834.96
# 213                        837.23                        861.00
# 214                        907.04                        927.58
#
#      Median weekly income in 2017  Median weekly income in 2018  \
# 0                         1281.29                       1298.42
# 1                         1281.29                       1298.42
# 2                         1095.00                       1146.58
# 3                         1271.12                       1337.75
# 4                         1100.77                       1156.08
# ..                            ...                           ...
# 210                        730.83                        716.00
# 211                        876.67                        913.94
# 212                        866.71                        917.48
# 213                        902.79                        939.52
# 214                        942.27                        986.69
#
#      Median weekly income in 2019  Median weekly income in 2020  \
# 0                         1311.26                       1324.23
# 1                         1311.26                       1324.23
# 2                         1183.29                       1221.19
# 3                         1376.55                       1416.49
# 4                         1189.43                       1223.74
# ..                            ...                           ...
# 210                        716.13                        716.25
# 211                        944.46                        976.00
# 212                        945.39                        974.15
# 213                        972.11                       1005.83
# 214                       1010.76                       1035.41
#
#      Median weekly income in 2021  Median weekly income in 2022
# 0                         1337.32                       1350.55
# 1                         1337.32                       1350.55
# 2                         1260.29                       1300.65
# 3                         1457.57                       1499.85
# 4                         1259.04                       1295.36
# ..                            ...                           ...
# 210                        716.38                        716.51
# 211                       1008.59                       1042.27
# 212                       1003.79                       1034.32
# 213                       1040.71                       1076.81
# 214                       1060.66                       1086.53
#
# [215 rows x 20 columns]

# %%
# get the past population
pop_past = pop.drop(list(pop.columns)[1:35],axis=1)
pop_past = pop_past.drop(list(pop_past.columns)[-3:],axis=1)

pop_past = pop_past.rename(columns={'Postcode':'postcode'})

pop_past.head()
# Out:
#    postcode  population density 2014  population density 2015  \
# 0      3002                   1853.0                   1866.0
# 1      3005                   3821.0                   4352.0
# 2      3008                   3821.0                   4352.0
# 3      3010                   1862.0                   1920.0
# 4      3050                   1862.0                   1920.0
#
#    population density 2016  population density 2017  population density 2018  \
# 0                   1888.0                   1895.0                   1865.0
# 1                   4930.0                   5801.0                   6433.0
# 2                   4930.0                   5801.0                   6433.0
# 3                   1974.0                   2046.0                   2061.0
# 4                   1974.0                   2046.0                   2061.0
#
#    population density 2019  population density 2020  population density 2021  \
# 0                   1867.0                   1854.0                   1711.0
# 1                   6823.0                   6949.0                   6642.0
# 2                   6823.0                   6949.0                   6642.0
# 3                   2074.0                   2080.0                   1862.0
# 4                   2074.0                   2080.0                   1862.0
#
#    population density 2022
# 0                   1737.0
# 1                   9448.0
# 2                   9448.0
# 3                   1894.0
# 4                   1894.0

# %%
merge = pd.merge(result, pop_past, how='left', on=['postcode'])
merge = merge.dropna()
subu = merge['suburb']
merge = merge[merge.columns[1:]].astype(float)
merge['suburb'] = list(subu)
merge
# Out:
#      postcode    2014    2015    2016    2017    2018    2019    2020    2021  \
# 0      3206.0  472.50  492.50  515.00  527.75  562.50  569.25  570.00  498.75
# 1      3206.0  472.50  492.50  515.00  527.75  562.50  569.25  570.00  498.75
# 3      3143.0  393.75  399.75  402.50  445.00  487.50  481.25  498.75  433.75
# 4      3054.0  515.00  530.00  527.50  545.00  566.25  579.25  588.75  577.50
# 5      3053.0  351.75  365.50  373.25  398.00  417.00  431.25  399.75  335.00
# ..        ...     ...     ...     ...     ...     ...     ...     ...     ...
# 210    3844.0  263.75  270.00  270.00  276.25  278.75  287.50  307.50  345.00
# 211    3677.0  247.50  250.00  260.00  266.25  274.25  287.50  299.50  340.00
# 212    3820.0  272.75  280.00  293.75  305.00  323.75  347.00  360.00  383.75
# 213    3280.0  280.00  285.00  288.75  290.00  300.00  322.50  342.50  365.00
# 214    3689.0  280.00  287.50  290.00  298.75  302.50  318.75  330.00  355.00
#
#       2022  ...  population density 2014  population density 2015  \
# 0    510.0  ...                   3317.0                   3416.0
# 1    510.0  ...                   3317.0                   3416.0
# 3    440.0  ...                   4267.0                   4311.0
# 4    587.5  ...                   3867.0                   3897.0
# 5    314.5  ...                   9913.0                  10546.0
# ..     ...  ...                      ...                      ...
# 210  370.0  ...                      3.0                      3.0
# 211  375.0  ...                    320.0                    323.0
# 212  400.0  ...                     51.0                     52.0
# 213  400.0  ...                    335.0                    340.0
# 214  385.0  ...                    501.0                    507.0
#
#      population density 2016  population density 2017  \
# 0                     3509.0                   3510.0
# 1                     3509.0                   3510.0
# 3                     4372.0                   4378.0
# 4                     3938.0                   3923.0
# 5                    11246.0                  11483.0
# ..                       ...                      ...
# 210                      3.0                      3.0
# 211                    329.0                    333.0
# 212                     54.0                     56.0
# 213                    344.0                    347.0
# 214                    515.0                    513.0
#
#      population density 2018  population density 2019  \
# 0                     3557.0                   3632.0
# 1                     3557.0                   3632.0
# 3                     4500.0                   4562.0
# 4                     3922.0                   3908.0
# 5                    11594.0                  11716.0
# ..                       ...                      ...
# 210                      3.0                      3.0
# 211                    338.0                    340.0
# 212                     58.0                     60.0
# 213                    352.0                    355.0
# 214                    513.0                    508.0
#
#      population density 2020  population density 2021  \
# 0                     3605.0                   3409.0
# 1                     3605.0                   3409.0
# 3                     4574.0                   4289.0
# 4                     3866.0                   3607.0
# 5                    11635.0                   9554.0
# ..                       ...                      ...
# 210                      3.0                      3.0
# 211                    342.0                    345.0
# 212                     63.0                     66.0
# 213                    359.0                    360.0
# 214                    503.0                    497.0
#
#      population density 2022         suburb
# 0                     3454.0    Albert Park
# 1                     3454.0    Middle Park
# 3                     4309.0       Armadale
# 4                     3604.0  Carlton North
# 5                     9856.0        Carlton
# ..                       ...            ...
# 210                      3.0      Traralgon
# 211                    348.0    Wanagaratta
# 212                     67.0       Warragul
# 213                    365.0    Warrnambool
# 214                    497.0        Wodonga
#
# [166 rows x 29 columns]

# %%
rent_da = []
income_da = []
pop_da = []
for i in range(1,10):
    rent_da.append(list(merge[merge.columns[i]]))
for j in range(10,19):
    income_da.append(list(merge[merge.columns[j]]))
for k in range(19,28):
    pop_da.append(list(merge[merge.columns[k]]))
rent_da =[float(x) for item in rent_da for x in item]
income_da =[float(x) for item in income_da for x in item]
pop_da =[float(x) for item in pop_da for x in item]

# %%
#get the final dataset to fit the model
data = {'rent': rent_da, 'income':income_da, 'population': pop_da}
dataset = pd.DataFrame(data)
dataset.head()
# Out:
#      rent   income  population
# 0  472.50  1249.52      3317.0
# 1  472.50  1249.52      3317.0
# 2  393.75  1194.02      4267.0
# 3  515.00  1032.40      3867.0
# 4  351.75   762.65      9913.0

# %% [markdown]
# # Creat The Prediction Dataframe

# %%
#get the population for 2023-2025
pop_fut = pop.drop(list(pop.columns)[1:44],axis=1)
pop_fut = pop_fut.rename(columns={'Postcode':'postcode'})
pop_fut
# Out:
#      postcode  population density 2023  population density 2024  \
# 0        3002                   1762.0                   1789.0
# 1        3005                  13437.0                  19111.0
# 2        3008                  13437.0                  19111.0
# 3        3010                   1928.0                   1961.0
# 4        3050                   1928.0                   1961.0
# ..        ...                      ...                      ...
# 587      3990                     38.0                     39.0
# 588      3991                     38.0                     39.0
# 589      3992                     38.0                     39.0
# 590      3995                     38.0                     39.0
# 591      3996                     38.0                     39.0
#
#      population density 2025
# 0                     1815.0
# 1                    27182.0
# 2                    27182.0
# 3                     1996.0
# 4                     1996.0
# ..                       ...
# 587                     40.0
# 588                     40.0
# 589                     40.0
# 590                     40.0
# 591                     40.0
#
# [592 rows x 4 columns]

# %%
#get the income for 2023-2025
income_fut = income.drop(list(income.columns)[1:11],axis=1)
income_fut = income_fut.rename(columns={'Postcode':'postcode'})
income_fut.head()
# Out:
#    postcode  Median weekly income in 2023  Median weekly income in 2024  \
# 0      3000                        523.56                        513.42
# 1      3001                        523.56                        513.42
# 2      8001                        523.56                        513.42
# 3      8003                        523.56                        513.42
# 4      8006                        523.56                        513.42
#
#    Median weekly income in 2025
# 0                        503.47
# 1                        503.47
# 2                        503.47
# 3                        503.47
# 4                        503.47

# %%
post = merge.drop(list(merge.columns)[1:],axis=1)
result2 = pd.merge(post, income_fut, how='left', on=['postcode'])
predict = pd.merge(result2, pop_fut, how='left', on=['postcode'])
predict
# Out:
#      postcode  Median weekly income in 2023  Median weekly income in 2024  \
# 0      3206.0                       1363.90                       1377.39
# 1      3206.0                       1363.90                       1377.39
# 2      3143.0                       1543.36                       1588.13
# 3      3054.0                       1332.73                       1371.18
# 4      3053.0                        732.41                        729.35
# ..        ...                           ...                           ...
# 161    3844.0                        716.63                        716.76
# 162    3677.0                       1077.08                       1113.04
# 163    3820.0                       1065.79                       1098.21
# 164    3280.0                       1114.16                       1152.81
# 165    3689.0                       1113.03                       1140.18
#
#      Median weekly income in 2025  population density 2023  \
# 0                         1391.01                   3500.0
# 1                         1391.01                   3500.0
# 2                         1634.20                   4329.0
# 3                         1410.74                   3601.0
# 4                          726.31                  10166.0
# ..                            ...                      ...
# 161                        716.89                      3.0
# 162                       1150.21                    350.0
# 163                       1131.62                     69.0
# 164                       1192.79                    370.0
# 165                       1167.98                    497.0
#
#      population density 2024  population density 2025
# 0                     3546.0                   3593.0
# 1                     3546.0                   3593.0
# 2                     4349.0                   4369.0
# 3                     3599.0                   3596.0
# 4                    10487.0                  10817.0
# ..                       ...                      ...
# 161                      3.0                      3.0
# 162                    353.0                    356.0
# 163                     70.0                     72.0
# 164                    375.0                    380.0
# 165                    497.0                    497.0
#
# [166 rows x 7 columns]

# %%
income_da2 = []
pop_da2 = []
for j in range(1,4):
    income_da2.append(list(predict[predict.columns[j]]))

for k in range(4,7):
    pop_da2.append(list(predict[predict.columns[k]]))
income_da2 =[float(x) for item in income_da2 for x in item]
pop_da2 =[float(x) for item in pop_da2 for x in item]

# %%
index = []
index.append(predict['postcode'].tolist()*3)
predict2 = {'index': index[0], 'income': income_da2, 'population':pop_da2}
pt = pd.DataFrame(predict2)
pt = pt.set_index('index')
pt
# Out:
#          income  population
# index
# 3206.0  1363.90      3500.0
# 3206.0  1363.90      3500.0
# 3143.0  1543.36      4329.0
# 3054.0  1332.73      3601.0
# 3053.0   732.41     10166.0
# ...         ...         ...
# 3844.0   716.89         3.0
# 3677.0  1150.21       356.0
# 3820.0  1131.62        72.0
# 3280.0  1192.79       380.0
# 3689.0  1167.98       497.0
#
# [498 rows x 2 columns]

# %%
#get the prediction dataframe for 2025
pt_25 = pt.iloc[332:498]
pt_25
# Out:
#          income  population
# index
# 3206.0  1391.01      3593.0
# 3206.0  1391.01      3593.0
# 3143.0  1634.20      4369.0
# 3054.0  1410.74      3596.0
# 3053.0   726.31     10817.0
# ...         ...         ...
# 3844.0   716.89         3.0
# 3677.0  1150.21       356.0
# 3820.0  1131.62        72.0
# 3280.0  1192.79       380.0
# 3689.0  1167.98       497.0
#
# [166 rows x 2 columns]

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Split data

# %%
X = dataset.iloc[:, 1:3].values
y = dataset.iloc[:, 0].values
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state=1)

# %% [markdown]
# ## Linear Regression

# %%
#First we choose linear regression to fit the model
linreg = LinearRegression()
model=linreg.fit(X_train, y_train)
y_pred_lr = model.predict(X_test)
print (model)
print (linreg.intercept_)
print (linreg.coef_)
# Out:
# LinearRegression()
# 133.47385522694861
# [0.23256072 0.01037388]

# %%
#draw receiver operating characteristic curve
plt.figure()
plt.plot(range(len(y_pred_lr)),y_pred_lr,'#559a90',label="predict")
plt.plot(range(len(y_pred_lr)),y_test,'#f9bf3e',label="test")
plt.legend(loc="upper right")
plt.xlabel("different suburb")
plt.ylabel('rent')
plt.title('ROC curve for Linear Forest')
plt.savefig('../plots/ROC curve for Linear Forest.png')
plt.show()

# %%
#evaluate the linear regression
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_lr))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_lr))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_lr)))
# Out:
# Mean Absolute Error: 41.91224170109746
# Mean Squared Error: 2905.013897403911
# Root Mean Squared Error: 53.89818083575651

# %% [markdown]
# ## Random Forest

# %%
# random forest regression
regressor = RandomForestRegressor(n_estimators=40, bootstrap = True, max_depth = 20, min_samples_leaf = 1, min_samples_split = 10, random_state=60)
regressor.fit(X_train, y_train)
y_pred_rf = regressor.predict(X_test)
random_forest_error=y_pred_rf-y_test

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# choose n_estimators from plot
scorel = []
for i in range(0,200,10):
    rfc = RandomForestRegressor(n_estimators=i+1,
                                 n_jobs=-1,
                                 random_state=90)
    score = cross_val_score(rfc,X_train,y_train,cv=5).mean()
    scorel.append(score)
plt.figure(figsize=[20,5])
plt.plot(range(1,201,10),scorel)
plt.show()

# %%
# use GridSearchCV to choose other important hyperparameters
param_grid = [
    {'bootstrap': [True],
     'max_depth': [10, 20, 30, None],
     'min_samples_leaf': [1, 2, 4],
     'min_samples_split': [2, 5, 10],
     'n_estimators': [30,40,50,60]},
    ]

forest_reg = RandomForestRegressor(random_state=42)
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error', return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#              param_grid=[{'bootstrap': [True], 'max_depth': [10, 20, 30, None],
#                           'min_samples_leaf': [1, 2, 4],
#                           'min_samples_split': [2, 5, 10],
#                           'n_estimators': [30, 40, 50, 60]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 20,
#  'min_samples_leaf': 1,
#  'min_samples_split': 10,
#  'n_estimators': 40}

# %%
#draw receiver operating characteristic curve
plt.figure()
plt.plot(range(len(y_pred_rf)),y_pred_rf,'#559a90',label="predict")
plt.plot(range(len(y_pred_rf)),y_test,'#f9bf3e',label="test")
plt.legend(loc="upper right")
plt.xlabel("different suburb")
plt.ylabel('rent')
plt.title('ROC curve for Random Forest')
plt.savefig('../plots/ROC curve for Random Forest.png')
plt.show()

# %%
# evaluate random forest
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_rf))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_rf))
print('Root Mean Squared Error:',
      np.sqrt(metrics.mean_squared_error(y_test, y_pred_rf)))
# Out:
# Mean Absolute Error: 32.78373503687157
# Mean Squared Error: 1939.2258904197674
# Root Mean Squared Error: 44.0366425879604

# %% [markdown]
# # Prediction

# %%
result = {'postcode': pt.iloc[332:498].index, '2025_pre': regressor.predict(pt_25)}
df_25 = DataFrame(result).reset_index()
df_25.head()
# Out:
# /Users/liuyiqun/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
#    index  postcode    2025_pre
# 0      0    3206.0  485.604772
# 1      1    3206.0  485.604772
# 2      2    3143.0  564.013904
# 3      3    3054.0  513.442287
# 4      4    3053.0  352.298823

# %%
df_22 = merge.drop(merge.columns[1:9], axis=1)
df_22 = df_22.drop(df_22.columns[2:], axis=1).reset_index()
df_22
# Out:
#      index  postcode   2022
# 0        0    3206.0  510.0
# 1        1    3206.0  510.0
# 2        3    3143.0  440.0
# 3        4    3054.0  587.5
# 4        5    3053.0  314.5
# ..     ...       ...    ...
# 161    210    3844.0  370.0
# 162    211    3677.0  375.0
# 163    212    3820.0  400.0
# 164    213    3280.0  400.0
# 165    214    3689.0  385.0
#
# [166 rows x 3 columns]

# %%
# get the rate 
df_25['2025_22_rate'] = (df_25['2025_pre'] - df_22['2022'])/df_22['2022']
df_25.head()
# Out:
#    index  postcode    2025_pre  2025_22_rate
# 0      0    3206.0  485.604772     -0.047834
# 1      1    3206.0  485.604772     -0.047834
# 2      2    3143.0  564.013904      0.281850
# 3      3    3054.0  513.442287     -0.126056
# 4      4    3053.0  352.298823      0.120187

# %%
sub = merge.drop(merge.columns[1:28], axis=1).reset_index(drop = True).reset_index()

# %%
rate_25 = pd.merge(df_25, sub, how = 'left', on = ['index','postcode'])
rate_25 = rate_25.drop(rate_25.columns[0], axis=1)
rate_25['postcode'] = rate_25['postcode'].astype(int)

# %%
#get top 10 suburbs with the highest rate
top10_rate_25 = rate_25.sort_values(by='2025_22_rate',ascending=False).head(10)
top10_rate_25.to_csv('../data/curated/top10_suburb.csv')
top10_rate_25
# Out:
#      postcode    2025_pre  2025_22_rate      suburb
# 152      3300  490.420210      0.582001    Hamilton
# 5        3052  440.549392      0.400793   Parkville
# 11       3184  579.671729      0.380171      Elwood
# 17       3181  553.678965      0.367109     Prahran
# 18       3181  553.678965      0.367109     Windsor
# 137      3357  498.962350      0.367020   Buninyong
# 156      3840  386.101054      0.354741     Morwell
# 109      3134  563.514800      0.341702    Ringwood
# 54       3194  584.959142      0.314515     Mentone
# 26       3124  596.418301      0.282620  Camberwell

# %%
import shapefile
shapes = shapefile.Reader("../data/raw/SAL_2021_AUST_GDA2020.shp").shapes()

# %%
import geopandas as gpd
suburb_shp = gpd.read_file("../data/raw/SAL_2021_AUST_GDA2020.shp")
suburb_shp[suburb_shp['STE_NAME21'] == 'Victoria']
# Out:
#      SAL_CODE21                              SAL_NAME21 STE_CODE21 STE_NAME21  \
# 4544      20001                                Abbeyard          2   Victoria
# 4545      20002                       Abbotsford (Vic.)          2   Victoria
# 4546      20003                              Aberfeldie          2   Victoria
# 4547      20004                               Aberfeldy          2   Victoria
# 4548      20005                                 Acheron          2   Victoria
# ...         ...                                     ...        ...        ...
# 7485      22942                                 Yuulong          2   Victoria
# 7486      22943                                 Zeerust          2   Victoria
# 7487      22944                               Zumsteins          2   Victoria
# 7488      29494                 No usual address (Vic.)          2   Victoria
# 7489      29797  Migratory - Offshore - Shipping (Vic.)          2   Victoria
#
#      AUS_CODE21 AUS_NAME21  AREASQKM21  \
# 4544        AUS  Australia    327.5008
# 4545        AUS  Australia      1.7405
# 4546        AUS  Australia      1.5515
# 4547        AUS  Australia     10.8319
# 4548        AUS  Australia     72.6602
# ...         ...        ...         ...
# 7485        AUS  Australia     52.1657
# 7486        AUS  Australia     18.0294
# 7487        AUS  Australia    256.5582
# 7488        AUS  Australia      0.0000
# 7489        AUS  Australia      0.0000
#
#                                              LOCI_URI21  SHAPE_Leng  \
# 4544  http://linked.data.gov.au/dataset/asgsed3/SAL/...    1.207678
# 4545  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.092990
# 4546  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.059374
# 4547  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.183199
# 4548  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.514040
# ...                                                 ...         ...
# 7485  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.447416
# 7486  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.211342
# 7487  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.810459
# 7488  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.000000
# 7489  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.000000
#
#       SHAPE_Area                                           geometry
# 4544    0.033162  POLYGON ((146.89824 -37.04602, 146.89947 -37.0...
# 4545    0.000178  POLYGON ((145.00195 -37.79665, 145.00190 -37.7...
# 4546    0.000159  POLYGON ((144.89576 -37.76514, 144.89547 -37.7...
# 4547    0.001107  POLYGON ((146.38814 -37.72232, 146.38808 -37.7...
# 4548    0.007381  POLYGON ((145.76731 -37.25433, 145.76757 -37.2...
# ...          ...                                                ...
# 7485    0.005404  POLYGON ((143.32185 -38.68969, 143.32203 -38.6...
# 7486    0.001808  POLYGON ((145.40454 -36.25294, 145.40479 -36.2...
# 7487    0.026011  POLYGON ((142.48512 -37.15733, 142.48443 -37.1...
# 7488    0.000000                                               None
# 7489    0.000000                                               None
#
# [2946 rows x 11 columns]

# %%
vic_suburb = suburb_shp[suburb_shp['STE_NAME21'] == 'Victoria']
vic_suburb = vic_suburb.rename(columns={'SAL_NAME21':'suburb'})
vic_suburb = vic_suburb.drop(list(vic_suburb.columns)[0], axis=1)
vic_suburb = vic_suburb.drop(list(vic_suburb.columns)[1:9], axis=1)
vic_suburb = vic_suburb.reset_index()
vic_suburb
# Out:
#       index                                  suburb  \
# 0      4544                                Abbeyard
# 1      4545                       Abbotsford (Vic.)
# 2      4546                              Aberfeldie
# 3      4547                               Aberfeldy
# 4      4548                                 Acheron
# ...     ...                                     ...
# 2941   7485                                 Yuulong
# 2942   7486                                 Zeerust
# 2943   7487                               Zumsteins
# 2944   7488                 No usual address (Vic.)
# 2945   7489  Migratory - Offshore - Shipping (Vic.)
#
#                                                geometry
# 0     POLYGON ((146.89824 -37.04602, 146.89947 -37.0...
# 1     POLYGON ((145.00195 -37.79665, 145.00190 -37.7...
# 2     POLYGON ((144.89576 -37.76514, 144.89547 -37.7...
# 3     POLYGON ((146.38814 -37.72232, 146.38808 -37.7...
# 4     POLYGON ((145.76731 -37.25433, 145.76757 -37.2...
# ...                                                 ...
# 2941  POLYGON ((143.32185 -38.68969, 143.32203 -38.6...
# 2942  POLYGON ((145.40454 -36.25294, 145.40479 -36.2...
# 2943  POLYGON ((142.48512 -37.15733, 142.48443 -37.1...
# 2944                                               None
# 2945                                               None
#
# [2946 rows x 3 columns]

# %%
top10_rate_25 = top10_rate_25.reset_index(drop=True)
top10_rate_25.loc[0, 'suburb'] = 'Hamilton (Vic.)'
top10_rate_25.loc[1, 'suburb'] = 'Parkville (Vic.)'
top10_rate_25.loc[4, 'suburb'] = 'Windsor (Vic.)'
top10_rate_25.loc[7, 'suburb'] = 'Ringwood (Vic.)'
top10_rate_25.loc[9, 'suburb'] = 'Camberwell (Vic.)'
top10_rate_25
# Out:
#    postcode    2025_pre  2025_22_rate             suburb
# 0      3300  490.420210      0.582001    Hamilton (Vic.)
# 1      3052  440.549392      0.400793   Parkville (Vic.)
# 2      3184  579.671729      0.380171             Elwood
# 3      3181  553.678965      0.367109            Prahran
# 4      3181  553.678965      0.367109     Windsor (Vic.)
# 5      3357  498.962350      0.367020          Buninyong
# 6      3840  386.101054      0.354741            Morwell
# 7      3134  563.514800      0.341702    Ringwood (Vic.)
# 8      3194  584.959142      0.314515            Mentone
# 9      3124  596.418301      0.282620  Camberwell (Vic.)

# %%
draw = pd.merge(vic_suburb, top10_rate_25,  how= 'right', on='suburb')
draw
# Out:
#    index             suburb  \
# 0   5672    Hamilton (Vic.)
# 1   6581   Parkville (Vic.)
# 2   5410             Elwood
# 3   6661            Prahran
# 4   7348     Windsor (Vic.)
# 5   4952          Buninyong
# 6   6312            Morwell
# 7   6717    Ringwood (Vic.)
# 8   6191            Mentone
# 9   4996  Camberwell (Vic.)
#
#                                             geometry  postcode    2025_pre  \
# 0  POLYGON ((142.07560 -37.78526, 142.07558 -37.7...      3300  490.420210
# 1  POLYGON ((144.95955 -37.78348, 144.95940 -37.7...      3052  440.549392
# 2  POLYGON ((144.98435 -37.87244, 144.98485 -37.8...      3184  579.671729
# 3  POLYGON ((145.00158 -37.85781, 145.00160 -37.8...      3181  553.678965
# 4  POLYGON ((144.99338 -37.85184, 144.99420 -37.8...      3181  553.678965
# 5  POLYGON ((143.88621 -37.64250, 143.88619 -37.6...      3357  498.962350
# 6  POLYGON ((146.42527 -38.24449, 146.42454 -38.2...      3840  386.101054
# 7  POLYGON ((145.23743 -37.82288, 145.23736 -37.8...      3134  563.514800
# 8  POLYGON ((145.07991 -37.98299, 145.07961 -37.9...      3194  584.959142
# 9  POLYGON ((145.09636 -37.84621, 145.09631 -37.8...      3124  596.418301
#
#    2025_22_rate
# 0      0.582001
# 1      0.400793
# 2      0.380171
# 3      0.367109
# 4      0.367109
# 5      0.367020
# 6      0.354741
# 7      0.341702
# 8      0.314515
# 9      0.282620

# %%
geoJSON = draw[['geometry']].to_json()

# %%
import folium
m = folium.Map(location=(-37.74582838114469, 142.0176194718262), tiles="Stamen Terrain", zoom_start=10)
# refer to the folium documentations on how to plot aggregated data.
folium.Choropleth(
    geo_data=geoJSON,
    name='choropleth',
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6f81e2d0156d6ba881620f0f660a0a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6f81e2d0156d6ba881620f0f660a0a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e6f81e2d0156d6ba881620f0f660a0a3 = L.map(
#                 &quot;map_e6f81e2d0156d6ba881620f0f660a0a3&quot;,
#                 {
#                     center: [-37.74582838114469, 142.0176194718262],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16850876fc07a19a94bb576f3a92d205 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e6f81e2d0156d6ba881620f0f660a0a3);
#
#
#             var choropleth_2fcf0eab22472bcf39b28a8d9503f7a9 = L.featureGroup(
#                 {}
#             ).addTo(map_e6f81e2d0156d6ba881620f0f660a0a3);
#
#
#         function geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef = L.geoJson(null, {
#                 onEachFeature: geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_onEachFeature,
#
#                 style: geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_styler,
#         });
#
#         function geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_add (data) {
#             geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef
#                 .addData(data)
#                 .addTo(choropleth_2fcf0eab22472bcf39b28a8d9503f7a9);
#         }
#             geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.07560266400003, -37.78525808699993], [142.07557945400004, -37.78533565699996], [142.07556744400006, -37.78537265699998], [142.072220463, -37.80335066699996], [142.07757337200007, -37.80461961699996], [142.07857267200006, -37.80483880699995], [142.09046645, -37.80735265799996], [142.08990544000005, -37.810321647999956], [142.0900154200001, -37.81034965799995], [142.09068142900003, -37.811461657999985], [142.08899645000008, -37.81270165799998], [142.0889434500001, -37.81336965799994], [142.09455243800005, -37.81540864799996], [142.09449743800008, -37.81542866799998], [142.09484045800002, -37.81822965799995], [142.09450644800006, -37.81852765799994], [142.0966904280001, -37.81995465799997], [142.0968734370001, -37.82376165799997], [142.09874942700003, -37.82651366899995], [142.09304546700002, -37.828794657999936], [142.09285646700005, -37.828898667999965], [142.08049464900012, -37.833829557999934], [142.08012843900008, -37.83378765799995], [142.07746763000011, -37.83419807699994], [142.07185842100012, -37.83537632699995], [142.0688124610001, -37.83602965699998], [142.0685413010001, -37.83598961699994], [142.06011440300006, -37.83595659599996], [142.06016039300005, -37.828751515999954], [142.06456532200002, -37.82870837699994], [142.06586545200003, -37.828701656999954], [142.0629574630001, -37.821432656999946], [142.062915233, -37.82133079699997], [142.062677473, -37.82132964699997], [142.0426264570001, -37.821392654999954], [142.0242904600001, -37.82144665399994], [142.02417746000003, -37.821539653999935], [142.02419845000009, -37.82633964399997], [142.00574846300003, -37.826364662999936], [142.005519423, -37.82642465299995], [141.99908845400012, -37.82636566299993], [141.99909542400007, -37.830684652999935], [141.99122646500007, -37.83063464299994], [141.99050146500008, -37.831720652999934], [141.98226743700002, -37.83177165199993], [141.98222045700004, -37.826065641999946], [141.98212946800004, -37.82149666199996], [141.98708145700004, -37.821495641999945], [141.98676448800006, -37.806695641999966], [141.96818946100007, -37.80673766099994], [141.949708535, -37.806775709999954], [141.9308614680001, -37.80681170899993], [141.93082284900004, -37.80114278899998], [141.93078645900005, -37.79579863899994], [141.93098049900004, -37.79579863899994], [141.93090848000008, -37.78505265899997], [141.93138050000005, -37.78479265899995], [141.9397754590001, -37.78150664899994], [141.9561364760001, -37.77509865999997], [141.95898146600007, -37.77472663999998], [141.95961846600005, -37.77474965999994], [141.96111445600002, -37.774214660999974], [141.9623034450001, -37.77323865099993], [141.96245648500008, -37.77305065099995], [141.96264548500005, -37.77298764

# %%
def get_centerpoint(lis):
    """
    program: calculate center point of park
    paras: longtitude, latutude
    """
    area = 0.0
    latitude,longtitude = 0.0,0.0
 
    a = len(lis)
    for i in range(a):
        lat = float(lis[i][1]) #weidu
        lng = float(lis[i][0]) #jingdu
 
        if i == 0:
            lat1 = float(lis[-1][1])
            lng1 = float(lis[-1][0])
 
        else:
            lat1 = float(lis[i-1][1])
            lng1 = float(lis[i-1][0])
 
        fg = (lat*lng1 - lng*lat1)/2.0
 
        area += fg
        latitude += fg*(lat+lat1)/3.0
        longtitude += fg*(lng+lng1)/3.0
 
    latitude = latitude/area
    longtitude = longtitude/area
 
    return latitude, longtitude

# %%
coordinates = []
for i in draw['index'].tolist():
    coordinates.append(get_centerpoint(shapes[i].points))
coordinates
# Out:
# [(-37.74582838114469, 142.0176194718262),
#  (-37.786753336090996, 144.95133018487266),
#  (-37.88077282186206, 144.98550326009283),
#  (-37.85177289331336, 145.00039954355438),
#  (-37.854535971620805, 144.99267667882972),
#  (-37.65190677851944, 143.8972756692839),
#  (-38.22756659114581, 146.41451510517106),
#  (-37.811426294868625, 145.23346050007007),
#  (-37.981573702484354, 145.06941347894409),
#  (-37.83835698780556, 145.0736777637629)]

# %%
type(shapes[0].points[0])
# Out:
# tuple

# %%
draw['center'] = coordinates
draw
# Out:
#    index             suburb  \
# 0   5672    Hamilton (Vic.)
# 1   6581   Parkville (Vic.)
# 2   5410             Elwood
# 3   6661            Prahran
# 4   7348     Windsor (Vic.)
# 5   4952          Buninyong
# 6   6312            Morwell
# 7   6717    Ringwood (Vic.)
# 8   6191            Mentone
# 9   4996  Camberwell (Vic.)
#
#                                             geometry  postcode    2025_pre  \
# 0  POLYGON ((142.07560 -37.78526, 142.07558 -37.7...      3300  490.420210
# 1  POLYGON ((144.95955 -37.78348, 144.95940 -37.7...      3052  440.549392
# 2  POLYGON ((144.98435 -37.87244, 144.98485 -37.8...      3184  579.671729
# 3  POLYGON ((145.00158 -37.85781, 145.00160 -37.8...      3181  553.678965
# 4  POLYGON ((144.99338 -37.85184, 144.99420 -37.8...      3181  553.678965
# 5  POLYGON ((143.88621 -37.64250, 143.88619 -37.6...      3357  498.962350
# 6  POLYGON ((146.42527 -38.24449, 146.42454 -38.2...      3840  386.101054
# 7  POLYGON ((145.23743 -37.82288, 145.23736 -37.8...      3134  563.514800
# 8  POLYGON ((145.07991 -37.98299, 145.07961 -37.9...      3194  584.959142
# 9  POLYGON ((145.09636 -37.84621, 145.09631 -37.8...      3124  596.418301
#
#    2025_22_rate                                     center
# 0      0.582001    (-37.74582838114469, 142.0176194718262)
# 1      0.400793  (-37.786753336090996, 144.95133018487266)
# 2      0.380171   (-37.88077282186206, 144.98550326009283)
# 3      0.367109   (-37.85177289331336, 145.00039954355438)
# 4      0.367109  (-37.854535971620805, 144.99267667882972)
# 5      0.367020    (-37.65190677851944, 143.8972756692839)
# 6      0.354741   (-38.22756659114581, 146.41451510517106)
# 7      0.341702  (-37.811426294868625, 145.23346050007007)
# 8      0.314515  (-37.981573702484354, 145.06941347894409)
# 9      0.282620    (-37.83835698780556, 145.0736777637629)

# %%
for i in range(len(draw)):
    zone_name =  draw['suburb'].tolist()[i]
    coord = draw['center'].tolist()[i]
    m.add_child(
        folium.Marker(location=coord, popup=zone_name)
    )
m.save('../plots/top_10 suburbs.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6f81e2d0156d6ba881620f0f660a0a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6f81e2d0156d6ba881620f0f660a0a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e6f81e2d0156d6ba881620f0f660a0a3 = L.map(
#                 &quot;map_e6f81e2d0156d6ba881620f0f660a0a3&quot;,
#                 {
#                     center: [-37.74582838114469, 142.0176194718262],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16850876fc07a19a94bb576f3a92d205 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e6f81e2d0156d6ba881620f0f660a0a3);
#
#
#             var choropleth_2fcf0eab22472bcf39b28a8d9503f7a9 = L.featureGroup(
#                 {}
#             ).addTo(map_e6f81e2d0156d6ba881620f0f660a0a3);
#
#
#         function geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef = L.geoJson(null, {
#                 onEachFeature: geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_onEachFeature,
#
#                 style: geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_styler,
#         });
#
#         function geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_add (data) {
#             geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef
#                 .addData(data)
#                 .addTo(choropleth_2fcf0eab22472bcf39b28a8d9503f7a9);
#         }
#             geo_json_ffd6c7adfc126d1f7f07f944d9c2d2ef_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.07560266400003, -37.78525808699993], [142.07557945400004, -37.78533565699996], [142.07556744400006, -37.78537265699998], [142.072220463, -37.80335066699996], [142.07757337200007, -37.80461961699996], [142.07857267200006, -37.80483880699995], [142.09046645, -37.80735265799996], [142.08990544000005, -37.810321647999956], [142.0900154200001, -37.81034965799995], [142.09068142900003, -37.811461657999985], [142.08899645000008, -37.81270165799998], [142.0889434500001, -37.81336965799994], [142.09455243800005, -37.81540864799996], [142.09449743800008, -37.81542866799998], [142.09484045800002, -37.81822965799995], [142.09450644800006, -37.81852765799994], [142.0966904280001, -37.81995465799997], [142.0968734370001, -37.82376165799997], [142.09874942700003, -37.82651366899995], [142.09304546700002, -37.828794657999936], [142.09285646700005, -37.828898667999965], [142.08049464900012, -37.833829557999934], [142.08012843900008, -37.83378765799995], [142.07746763000011, -37.83419807699994], [142.07185842100012, -37.83537632699995], [142.0688124610001, -37.83602965699998], [142.0685413010001, -37.83598961699994], [142.06011440300006, -37.83595659599996], [142.06016039300005, -37.828751515999954], [142.06456532200002, -37.82870837699994], [142.06586545200003, -37.828701656999954], [142.0629574630001, -37.821432656999946], [142.062915233, -37.82133079699997], [142.062677473, -37.82132964699997], [142.0426264570001, -37.821392654999954], [142.0242904600001, -37.82144665399994], [142.02417746000003, -37.821539653999935], [142.02419845000009, -37.82633964399997], [142.00574846300003, -37.826364662999936], [142.005519423, -37.82642465299995], [141.99908845400012, -37.82636566299993], [141.99909542400007, -37.830684652999935], [141.99122646500007, -37.83063464299994], [141.99050146500008, -37.831720652999934], [141.98226743700002, -37.83177165199993], [141.98222045700004, -37.826065641999946], [141.98212946800004, -37.82149666199996], [141.98708145700004, -37.821495641999945], [141.98676448800006, -37.806695641999966], [141.96818946100007, -37.80673766099994], [141.949708535, -37.806775709999954], [141.9308614680001, -37.80681170899993], [141.93082284900004, -37.80114278899998], [141.93078645900005, -37.79579863899994], [141.93098049900004, -37.79579863899994], [141.93090848000008, -37.78505265899997], [141.93138050000005, -37.78479265899995], [141.9397754590001, -37.78150664899994], [141.9561364760001, -37.77509865999997], [141.95898146600007, -37.77472663999998], [141.95961846600005, -37.77474965999994], [141.96111445600002, -37.774214660999974], [141.9623034450001, -37.77323865099993], [141.96245648500008, -37.77305065099995], [141.96264548500005, -37.77298764
