# %% [markdown]
# <Font size=5> External Data Preprocessing

# %% [markdown]
# <font size=3>School Location

# %%
import pandas as pd
import geopandas as gpd

# %%
school_df_1819 = pd.read_csv('../data/raw/school_location_18_19.csv',encoding='cp1252')
school_df_20 = pd.read_csv('../data/raw/school_location_20.csv')
school_df_21 = pd.read_csv('../data/raw/school_location_21.csv',encoding='cp1252')

# %%
school_df_1819.head()
# Out:
#   Education_Sector  Entity_Type  School_No  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type School_Status  \
# 0                 Alberton Primary School     Primary             O
# 1  Allansford and District Primary School     Primary             O
# 2                    Avoca Primary School     Primary             O
# 3                   Avenel Primary School     Primary             O
# 4               Warrandyte Primary School     Primary             O
#
#        Address_Line_1 Address_Line_2 Address_Town Address_State  ...  \
# 0   21 Thomson Street            NaN     Alberton           VIC  ...
# 1        Frank Street            NaN   Allansford           VIC  ...
# 2  118 Barnett Street            NaN        Avoca           VIC  ...
# ...

# %%
school_df_20.head()
# Out:
#   Education_Sector  Entity_Type  SCHOOL_NO  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type School_Status  \
# 0                 Alberton Primary School     Primary             O
# 1  Allansford and District Primary School     Primary             O
# 2                    Avoca Primary School     Primary             O
# 3                   Avenel Primary School     Primary             O
# 4               Warrandyte Primary School     Primary             O
#
#        Address_Line_1 Address_Line_2 Address_Town Address_State  ...  \
# 0   21 Thomson Street            NaN     Alberton           VIC  ...
# 1        Frank Street            NaN   Allansford           VIC  ...
# 2  118 Barnett Street            NaN        Avoca           VIC  ...
# ...

# %%
school_df_21.head()
# Out:
#   Education_Sector  Entity_Type  SCHOOL_NO  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type School_Status  \
# 0                 Alberton Primary School     Primary             O
# 1  Allansford and District Primary School     Primary             O
# 2                    Avoca Primary School     Primary             O
# 3                   Avenel Primary School     Primary             O
# 4               Warrandyte Primary School     Primary             O
#
#        Address_Line_1 Address_Line_2 Address_Town Address_State  ...  \
# 0   21 Thomson Street            NaN     Alberton           VIC  ...
# 1        Frank Street            NaN   Allansford           VIC  ...
# 2  118 Barnett Street            NaN        Avoca           VIC  ...
# ...

# %%
school_df_1819 = school_df_1819[['Education_Sector','School_Name','School_Type','Address_Line_1','Address_Town','Address_Postcode','LGA_Name','X','Y']]
school_df_20 = school_df_20[['Education_Sector','School_Name','School_Type','Address_Line_1','Address_Town','Address_Postcode','LGA_Name','X','Y']]
school_df_21 = school_df_21[['Education_Sector','School_Name','School_Type','Address_Line_1','Address_Town','Address_Postcode','LGA_Name','X','Y']]

# %%
school_df_1819.isnull().sum().sort_values(ascending=False)
# Out:
# Education_Sector    0
# School_Name         0
# School_Type         0
# Address_Line_1      0
# Address_Town        0
# Address_Postcode    0
# LGA_Name            0
# X                   0
# Y                   0
# dtype: int64

# %%
school_df_20.isnull().sum().sort_values(ascending=False)
# Out:
# Education_Sector    0
# School_Name         0
# School_Type         0
# Address_Line_1      0
# Address_Town        0
# Address_Postcode    0
# LGA_Name            0
# X                   0
# Y                   0
# dtype: int64

# %%
school_df_21.isnull().sum().sort_values(ascending=False)
# Out:
# Education_Sector    0
# School_Name         0
# School_Type         0
# Address_Line_1      0
# Address_Town        0
# Address_Postcode    0
# LGA_Name            0
# X                   0
# Y                   0
# dtype: int64

# %%
school_df_1819.to_csv('../data/curated/school_df_1819_preprocessed.csv')
school_df_20.to_csv('../data/curated/school_df_20_preprocessed.csv')
school_df_21.to_csv('../data/curated/school_df_21_preprocessed.csv')

# %% [markdown]
# <Font size=3> Hospital Location

# %%
hospital_df= pd.read_csv('../data/raw/hospital_location.csv')
hospital_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/jnniu/Group55/generic-real-estate-consulting-project-group-55/notebooks/external_data_preprocess.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jnniu/Group55/generic-real-estate-consulting-project-group-55/notebooks/external_data_preprocess.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> hospital_df= pd.read_csv('../data/raw/hospital_location.csv')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jnniu/Group55/generic-real-estate-consulting-project-group-55/notebooks/external_data_preprocess.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> hospital_df.head()
#
# File ~/miniconda3/envs/group55/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
hospital_df = hospital_df[['Formal Name','Emergency Capable','Location Address','Suburb','Postcode','Agency Type']]
hospital_df.head()
# Out:
#                             Formal Name Emergency Capable   Location Address  \
# 0                    Albert Road Clinic                NO  31-33 Albert Road
# 1                 Albury Wodonga Health               YES  69 Vermont Street
# 2  Albury Wodonga Health, Albury Campus               YES            Borella
# 3             Alexandra District Health                NO   20 Cooper Street
# 4                         Alfred Health                NO    Commercial Road
#
#             Suburb  Postcode       Agency Type
# 0  South Melbourne      3205  Private Hospital
# 1          Wodonga      3690   Public Hospital
# 2           Albury      2640   Public Hospital
# 3        Alexandra      3714   Public Hospital
# 4        Melbourne      3004   Public Hospital

# %%
hospital_df.isnull().sum().sort_values(ascending=False)
# Out:
# Formal Name          0
# Emergency Capable    0
# Location Address     0
# Suburb               0
# Postcode             0
# Agency Type          0
# dtype: int64

# %%
hospital_df.to_csv('../data/curated/hospital_preprocessed.csv')

# %% [markdown]
# <font size=3> Population Data

# %%
population_df=pd.read_excel('../data/raw/population.xlsx',sheet_name='Table 1')
population = population_df.loc[8:2461]
pop_drop = population.dropna(axis='columns',how = 'all')
pop_drop.to_csv('../data/raw/population_2.csv', encoding='utf-8')

# %%
pop_drop
# Out:
#                  Australian Bureau of Statistics  \
# 8                                              1
# 9                                              1
# 10                                             1
# 11                                             1
# 12                                             1
# ...                                          ...
# 2457                                           8
# 2458                                           9
# 2459                                           9
# 2460                                           9
# 2461                                           9
#
#                         Unnamed: 1 Unnamed: 2                    Unnamed: 3  \
# 8                  New South Wales      1RNSW                   Rest of NSW
# 9                  New South Wales      1RNSW                   Rest of NSW
# 10                 New South Wales      1RNSW                   Rest of NSW
# ...

# %%
population=pd.read_csv('../data/raw/population_2.csv',header=0,names=['S/T code','S/T name', 'GCCSA code', 'GCCSA name',\
                                                                      'SA4 code', 'SA4 name', 'SA3 code', 'SA3 name', 'SA2 code',\
                                                                      'SA2 name', '2001','2002', '2003','2004', '2005','2006',
                                                                      '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',\
                                                                      '2016','2017','2018', '2019','2020','2021','change 2011-2021 number','change 2011-2021 %',\
                                                                      'Area km2','population density 2021(persons/km2)'])
VIC_population = population.loc[population['S/T name']=='Victoria']

# %%
VIC_population
# Out:
#       S/T code  S/T name GCCSA code    GCCSA name  SA4 code  \
# 650          2  Victoria      2RVIC  Rest of Vic.       201
# 651          2  Victoria      2RVIC  Rest of Vic.       201
# 652          2  Victoria      2RVIC  Rest of Vic.       201
# 653          2  Victoria      2RVIC  Rest of Vic.       201
# 654          2  Victoria      2RVIC  Rest of Vic.       201
# ...        ...       ...        ...           ...       ...
# 1167         2  Victoria      2RVIC  Rest of Vic.       217
# 1168         2  Victoria      2RVIC  Rest of Vic.       217
# 1169         2  Victoria      2RVIC  Rest of Vic.       217
# 1170         2  Victoria      2RVIC  Rest of Vic.       217
# 1171         2  Victoria      2RVIC  Rest of Vic.       217
#
#                         SA4 name  SA3 code             SA3 name   SA2 code  \
# 650                     Ballarat     20101             Ballarat  201011001
# 651                     Ballarat     20101             Ballarat  201011002
# ...

# %%
select_population = VIC_population.loc[:, ['S/T name', 'SA2 name', '2001','2002', '2003','2004', '2005','2006',\
                                           '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',\
                                           '2016','2017','2018', '2019','2020','2021','change 2011-2021 number','change 2011-2021 %',\
                                           'Area km2','population density 2021(persons/km2)']]

# %%
select_population
# Out:
#       S/T name             SA2 name   2001   2002   2003   2004   2005   2006  \
# 650   Victoria            Alfredton   5756   6092   6293   6480   6648   6761
# 651   Victoria             Ballarat  11497  11708  12015  12189  12269  12356
# 652   Victoria            Buninyong   5320   5399   5557   5620   5857   6037
# 653   Victoria            Delacombe   4154   4225   4371   4465   4704   5041
# 654   Victoria        Smythes Creek   3317   3378   3411   3473   3508   3542
# ...        ...                  ...    ...    ...    ...    ...    ...    ...
# 1167  Victoria                Otway   3452   3479   3511   3511   3492   3459
# 1168  Victoria         Moyne - East   6718   6704   6676   6643   6638   6652
# 1169  Victoria         Moyne - West   8317   8387   8450   8487   8517   8601
# 1170  Victoria  Warrnambool - North  17053  17449  17726  17937  18172  18528
# 1171  Victoria  Warrnambool - South  12506  12578  12639  12697  12748  12792
#
# ...

# %%
postcode_SA2 = pd.read_csv('../data/raw/postcode_info.csv')
postcode_SA2
# Out:
#       Unnamed: 0     ID  Postcode        Locality State   Longitude  \
# 0              0   4746      3000       MELBOURNE   VIC  144.956776
# 1              1   4747      3001       MELBOURNE   VIC  144.956776
# 2              2   4748      3002  EAST MELBOURNE   VIC  144.982207
# 3              3   4749      3003  WEST MELBOURNE   VIC  144.949592
# 4              4   4750      3004       MELBOURNE   VIC  144.970161
# ...          ...    ...       ...             ...   ...         ...
# 3529        3529  11311      8111       MELBOURNE   VIC  144.970161
# 3530        3530  11312      8120       MELBOURNE   VIC  144.970161
# 3531        3531  11313      8205       MELBOURNE   VIC  144.970161
# 3532        3532  11331      8785       DANDENONG   VIC  145.208504
# 3533        3533  23878      9999      NORTH POLE   VIC  144.956776
#
#        Latitude           Category               Type      SA3  ... MMM 2015  \
# ...

# %%
attribute = postcode_SA2.loc[:,['Postcode','Longitude','Latitude','SA2 NAME 2016']]
drop_dup = attribute.drop_duplicates(subset=['Postcode'])
drop_dup = drop_dup.drop_duplicates(subset=['Longitude','Latitude'])
rename = drop_dup.rename(columns={'SA2 NAME 2016':'SA2 name'})

# %%
rename
# Out:
#       Postcode   Longitude   Latitude        SA2 name
# 0         3000  144.956776 -37.817403       Melbourne
# 2         3002  144.982207 -37.818517  East Melbourne
# 3         3003  144.949592 -37.810871  West Melbourne
# 4         3004  144.970161 -37.844246       Southbank
# 7         3005  144.950858 -37.824608       Docklands
# ...        ...         ...        ...             ...
# 3512      8004  145.468994 -36.558800     Albert Park
# 3514      8006  144.959306 -37.809701       Melbourne
# 3517      8009  144.964531 -37.817201       Melbourne
# 3518      8010  146.293728 -38.185857          Romsey
# 3519      8011  144.961746 -37.811314       Melbourne
#
# [724 rows x 4 columns]

# %%
merge_data = pd.DataFrame(pd.merge(rename, select_population, on='SA2 name', how='inner'))

# %%
merge_data.to_csv('../data/curated/population_postcode_SA2.csv')

# %%
merge_data
# Out:
#      Postcode   Longitude   Latitude               SA2 name  S/T name   2001  \
# 0        3002  144.982207 -37.818517         East Melbourne  Victoria   3731
# 1        3005  144.950858 -37.824608              Docklands  Victoria    154
# 2        3008  144.948039 -37.814719              Docklands  Victoria    154
# 3        3010  144.961351 -37.796152              Parkville  Victoria   5332
# 4        3050  144.954581 -37.800324              Parkville  Victoria   5332
# ..        ...         ...        ...                    ...       ...    ...
# 587      3990  145.501279 -38.455399  Wonthaggi - Inverloch  Victoria  17647
# 588      3991  145.466781 -38.483041  Wonthaggi - Inverloch  Victoria  17647
# 589      3992  145.534315 -38.569135  Wonthaggi - Inverloch  Victoria  17647
# 590      3995  145.630713 -38.578071  Wonthaggi - Inverloch  Victoria  17647
# 591      3996  145.745609 -38.629561  Wonthaggi - Inverloch  Victoria  17647
#
# ...

# %%
merge_data["new"]=merge_data["2021"]*merge_data["change 2011-2021 %"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vb/kjwyk4kn79s81t6y46g8crxw0000gn/T/ipykernel_19859/4261582803.py in <module>
# ----> 1 merge_data["new"]=merge_data["2021"]*merge_data["change 2011-2021 %"]
#
# NameError: name 'merge_data' is not defined

# %% [markdown]
# Park Location

# %%
sf = gpd.read_file("../data/raw/park/Parks_and_Open_Space.shp")
sf.head()
# Out:
#    OBJECTID  ParkID               Park_Name       Alias_Name ParkClassC  \
# 0         1     150            Adanac Green     Adanac Green        GRN
# 1         2       8   Bay Street Playground   Alexander Park         NP
# 2         3       1            Alston Green     Alston Green        GRN
# 3         4       2  Washington Avenue Park     Arbutus Park         NP
# 4         5       3         Arm Street Park  Arm Street Park         NP
#
#   BallDiamon Concession DogsOffLea Horticultu LawnBowlin  ... BallDiam_1  \
# 0       None       None       None       None       None  ...        NaN
# 1       None       None        Yes       None       None  ...        NaN
# 2       None       None       None       None       None  ...        NaN
# 3       None       None        Yes       None       None  ...        NaN
# 4       None       None       None       None       None  ...        NaN
#
#   SportFie_1 TennisCo_1 DogsOffL_1 Trail1 LawnBowl_1 WaterView1  SHAPE_Leng  \
# ...

# %%
# present the geometry using coordinate

sf['geometry'] = sf['geometry'].to_crs("+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs")
sf.head()
# Out:
#    OBJECTID  ParkID               Park_Name       Alias_Name ParkClassC  \
# 0         1     150            Adanac Green     Adanac Green        GRN
# 1         2       8   Bay Street Playground   Alexander Park         NP
# 2         3       1            Alston Green     Alston Green        GRN
# 3         4       2  Washington Avenue Park     Arbutus Park         NP
# 4         5       3         Arm Street Park  Arm Street Park         NP
#
#   BallDiamon Concession DogsOffLea Horticultu LawnBowlin  ... BallDiam_1  \
# 0       None       None       None       None       None  ...        NaN
# 1       None       None        Yes       None       None  ...        NaN
# 2       None       None       None       None       None  ...        NaN
# 3       None       None        Yes       None       None  ...        NaN
# 4       None       None       None       None       None  ...        NaN
#
#   SportFie_1 TennisCo_1 DogsOffL_1 Trail1 LawnBowl_1 WaterView1  SHAPE_Leng  \
# ...

# %%
park_name = list(sf['Park_Name'])
park_geo = list(sf['geometry'])

park_geo

# %%
# save the park's coordinate into a csv

park = {'Park_Name': list(sf['Park_Name']), 'Geometry': list(sf['geometry'])}

df_park = pd.DataFrame(park, columns=['Park_Name', 'Geometry'])
df_park.to_csv('../data/curated/park.csv')

# %%
import numpy as np
data = np.random.randn(3, 4)
data
# Out:
# array([[-1.32587924,  0.2864321 , -2.36485631, -0.10497695],
#        [-1.0140295 , -0.93843088,  0.31584296, -0.1649103 ],
#        [-1.72463784, -1.39731872, -0.14199401,  1.56319264]])
