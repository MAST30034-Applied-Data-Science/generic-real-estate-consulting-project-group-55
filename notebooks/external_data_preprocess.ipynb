# %% [markdown]
# <Font size=5> External Data Preprocessing

# %% [markdown]
# <font size=3>School Location

# %%
import pandas as pd

# %%
school_df_1819 = pd.read_csv('../data/raw/school_location_18_19.csv',encoding='cp1252')
school_df_20 = pd.read_csv('../data/raw/school_location_20.csv')
school_df_21 = pd.read_csv('../data/raw/school_location_21.csv',encoding='cp1252')

# %%
school_df_1819.head()
# Out:
#   Education_Sector  Entity_Type  School_No  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type School_Status  \
# 0                 Alberton Primary School     Primary             O
# 1  Allansford and District Primary School     Primary             O
# 2                    Avoca Primary School     Primary             O
# 3                   Avenel Primary School     Primary             O
# 4               Warrandyte Primary School     Primary             O
#
#        Address_Line_1 Address_Line_2 Address_Town Address_State  ...  \
# 0   21 Thomson Street            NaN     Alberton           VIC  ...
# 1        Frank Street            NaN   Allansford           VIC  ...
# 2  118 Barnett Street            NaN        Avoca           VIC  ...
# 3  40 Anderson Street            NaN       Avenel           VIC  ...
# 4  5-11 Forbes Street            NaN   Warrandyte           VIC  ...
#
#    Postal_Address_Line_1 Postal_Address_Line_2 Postal_Town Postal_State  \
# 0      21 Thomson Street                   NaN    ALBERTON          VIC
# 1           Frank Street                   NaN  ALLANSFORD          VIC
# 2             P O Box 12                   NaN       AVOCA          VIC
# 3     40 Anderson Street                   NaN      AVENEL          VIC
# 4     5-11 Forbes Street                   NaN  WARRANDYTE          VIC
#
#   Postal_Postcode  Full_Phone_No LGA_ID         LGA_Name           X  \
# 0            3971   03 5183 2412    681   Wellington (S)  146.666601
# 1            3277   03 5565 1382    673  Warrnambool (C)  142.590393
# 2            3467   03 5465 3176    599     Pyrenees (S)  143.475649
# 3            3664   03 5796 2264    643  Strathbogie (S)  145.234722
# 4            3113   03 9844 3537    421   Manningham (C)  145.213980
#
#            Y
# 0 -38.617713
# 1 -38.386281
# 2 -37.084502
# 3 -36.901368
# 4 -37.742675
#
# [5 rows x 21 columns]

# %%
school_df_20.head()
# Out:
#   Education_Sector  Entity_Type  SCHOOL_NO  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type School_Status  \
# 0                 Alberton Primary School     Primary             O
# 1  Allansford and District Primary School     Primary             O
# 2                    Avoca Primary School     Primary             O
# 3                   Avenel Primary School     Primary             O
# 4               Warrandyte Primary School     Primary             O
#
#        Address_Line_1 Address_Line_2 Address_Town Address_State  ...  \
# 0   21 Thomson Street            NaN     Alberton           VIC  ...
# 1        Frank Street            NaN   Allansford           VIC  ...
# 2  118 Barnett Street            NaN        Avoca           VIC  ...
# 3  40 Anderson Street            NaN       Avenel           VIC  ...
# 4  5-11 Forbes Street            NaN   Warrandyte           VIC  ...
#
#    Postal_Address_Line_1 Postal_Address_Line_2 Postal_Town Postal_State  \
# 0      21 Thomson Street                   NaN    ALBERTON          VIC
# 1           Frank Street                   NaN  ALLANSFORD          VIC
# 2             P O Box 12                   NaN       AVOCA          VIC
# 3     40 Anderson Street                   NaN      AVENEL          VIC
# 4     5-11 Forbes Street                   NaN  WARRANDYTE          VIC
#
#   Postal_Postcode  Full_Phone_No LGA_ID         LGA_Name           X  \
# 0            3971   03 5183 2412    681   Wellington (S)  146.666601
# 1            3277   03 5565 1382    673  Warrnambool (C)  142.590393
# 2            3467   03 5465 3176    599     Pyrenees (S)  143.475649
# 3            3664   03 5796 2264    643  Strathbogie (S)  145.234722
# 4            3113   03 9844 3537    421   Manningham (C)  145.213980
#
#            Y
# 0 -38.617713
# 1 -38.386281
# 2 -37.084502
# 3 -36.901368
# 4 -37.742675
#
# [5 rows x 21 columns]

# %%
school_df_21.head()
# Out:
#   Education_Sector  Entity_Type  SCHOOL_NO  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type School_Status  \
# 0                 Alberton Primary School     Primary             O
# 1  Allansford and District Primary School     Primary             O
# 2                    Avoca Primary School     Primary             O
# 3                   Avenel Primary School     Primary             O
# 4               Warrandyte Primary School     Primary             O
#
#        Address_Line_1 Address_Line_2 Address_Town Address_State  ...  \
# 0   21 Thomson Street            NaN     Alberton           VIC  ...
# 1        Frank Street            NaN   Allansford           VIC  ...
# 2  118 Barnett Street            NaN        Avoca           VIC  ...
# 3  40 Anderson Street            NaN       Avenel           VIC  ...
# 4  5-11 Forbes Street            NaN   Warrandyte           VIC  ...
#
#    Postal_Address_Line_1 Postal_Address_Line_2 Postal_Town Postal_State  \
# 0      21 Thomson Street                   NaN    ALBERTON          VIC
# 1           Frank Street                   NaN  ALLANSFORD          VIC
# 2             P O Box 12                   NaN       AVOCA          VIC
# 3     40 Anderson Street                   NaN      AVENEL          VIC
# 4     5-11 Forbes Street                   NaN  WARRANDYTE          VIC
#
#   Postal_Postcode  Full_Phone_No LGA_ID         LGA_Name           X  \
# 0            3971   03 5183 2412    681   Wellington (S)  146.666601
# 1            3277   03 5565 1382    673  Warrnambool (C)  142.590393
# 2            3467   03 5465 3176    599     Pyrenees (S)  143.475649
# 3            3664   03 5796 2264    643  Strathbogie (S)  145.234722
# 4            3113   03 9844 3537    421   Manningham (C)  145.213980
#
#            Y
# 0 -38.617713
# 1 -38.386281
# 2 -37.084502
# 3 -36.901368
# 4 -37.742675
#
# [5 rows x 21 columns]

# %%
school_df_1819 = school_df_1819[['Education_Sector','School_Name','School_Type','Address_Line_1','Address_Town','Address_Postcode','LGA_Name','X','Y']]
school_df_20 = school_df_20[['Education_Sector','School_Name','School_Type','Address_Line_1','Address_Town','Address_Postcode','LGA_Name','X','Y']]
school_df_21 = school_df_21[['Education_Sector','School_Name','School_Type','Address_Line_1','Address_Town','Address_Postcode','LGA_Name','X','Y']]

# %%
school_df_1819.isnull().sum().sort_values(ascending=False)
# Out:
# Education_Sector    0
# School_Name         0
# School_Type         0
# Address_Line_1      0
# Address_Town        0
# Address_Postcode    0
# LGA_Name            0
# X                   0
# Y                   0
# dtype: int64

# %%
school_df_20.isnull().sum().sort_values(ascending=False)
# Out:
# Education_Sector    0
# School_Name         0
# School_Type         0
# Address_Line_1      0
# Address_Town        0
# Address_Postcode    0
# LGA_Name            0
# X                   0
# Y                   0
# dtype: int64

# %%
school_df_21.isnull().sum().sort_values(ascending=False)
# Out:
# Education_Sector    0
# School_Name         0
# School_Type         0
# Address_Line_1      0
# Address_Town        0
# Address_Postcode    0
# LGA_Name            0
# X                   0
# Y                   0
# dtype: int64

# %%
school_df_1819.to_csv('../data/curated/school_df_1819_preprocessed.csv')
school_df_20.to_csv('../data/curated/school_df_20_preprocessed.csv')
school_df_21.to_csv('../data/curated/school_df_21_preprocessed.csv')

# %% [markdown]
# <Font size=3> Hospital Location

# %%
hospital_df= pd.read_csv('../data/raw/hospital_location.csv')
hospital_df.head()
# Out:
#    Hospital ID                           Formal Name  \
# 0         5488                    Albert Road Clinic
# 1         3485                 Albury Wodonga Health
# 2        12990  Albury Wodonga Health, Albury Campus
# 3         3491             Alexandra District Health
# 4        11519                         Alfred Health
#
#                              Other Name Emergency Capable   Location Address  \
# 0                    Albert Road Clinic                NO  31-33 Albert Road
# 1                 Albury Wodonga Health               YES  69 Vermont Street
# 2  Albury Wodonga Health, Albury Campus               YES            Borella
# 3             Alexandra District Health                NO   20 Cooper Street
# 4                         Alfred Health                NO    Commercial Road
#
#             Suburb  Postcode  Access Point Category       Agency Type
# 0  South Melbourne      3205           NaN  PRIVATE  Private Hospital
# 1          Wodonga      3690           NaN   PUBLIC   Public Hospital
# 2           Albury      2640           NaN   PUBLIC   Public Hospital
# 3        Alexandra      3714           NaN   PUBLIC   Public Hospital
# 4        Melbourne      3004           NaN   PUBLIC   Public Hospital

# %%
hospital_df = hospital_df[['Formal Name','Emergency Capable','Location Address','Suburb','Postcode','Agency Type']]
hospital_df.head()
# Out:
#                             Formal Name Emergency Capable   Location Address  \
# 0                    Albert Road Clinic                NO  31-33 Albert Road
# 1                 Albury Wodonga Health               YES  69 Vermont Street
# 2  Albury Wodonga Health, Albury Campus               YES            Borella
# 3             Alexandra District Health                NO   20 Cooper Street
# 4                         Alfred Health                NO    Commercial Road
#
#             Suburb  Postcode       Agency Type
# 0  South Melbourne      3205  Private Hospital
# 1          Wodonga      3690   Public Hospital
# 2           Albury      2640   Public Hospital
# 3        Alexandra      3714   Public Hospital
# 4        Melbourne      3004   Public Hospital

# %%
hospital_df.isnull().sum().sort_values(ascending=False)
# Out:
# Formal Name          0
# Emergency Capable    0
# Location Address     0
# Suburb               0
# Postcode             0
# Agency Type          0
# dtype: int64

# %%
hospital_df.to_csv('../data/curated/hospital_preprocessed.csv')

# %% [markdown]
# <font size=3> Population Data

# %%
population_df=pd.read_excel('../data/raw/population.xlsx',sheet_name='Table 3')
population = population_df[8:]
population.to_csv('../data/raw/population_2.csv', encoding='utf-8')
population
# Out:
#                         Australian Bureau of Statistics Unnamed: 1  \
# 8                                                  2001          1
# 9                                                  2001          1
# 10                                                 2001          1
# 11                                                 2001          1
# 12                                                 2001          1
# ...                                                 ...        ...
# 51458                                               NaN        NaN
# 51459                                               NaN        NaN
# 51460  Source: Regional population by age and sex, 2021        NaN
# 51461                                               NaN        NaN
# 51462                  © Commonwealth of Australia 2022        NaN
#
#             Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5      Unnamed: 6  \
# 8      New South Wales      1RNSW  Rest of NSW        101  Capital Region
# 9      New South Wales      1RNSW  Rest of NSW        101  Capital Region
# 10     New South Wales      1RNSW  Rest of NSW        101  Capital Region
# 11     New South Wales      1RNSW  Rest of NSW        101  Capital Region
# 12     New South Wales      1RNSW  Rest of NSW        101  Capital Region
# ...                ...        ...          ...        ...             ...
# 51458              NaN        NaN          NaN        NaN             NaN
# 51459              NaN        NaN          NaN        NaN             NaN
# 51460              NaN        NaN          NaN        NaN             NaN
# 51461              NaN        NaN          NaN        NaN             NaN
# 51462              NaN        NaN          NaN        NaN             NaN
#
#       Unnamed: 7  Unnamed: 8 Unnamed: 9  ... Unnamed: 20 Unnamed: 21  \
# 8          10102  Queanbeyan  101021007  ...         221         262
# 9          10102  Queanbeyan  101021008  ...         675         585
# 10         10102  Queanbeyan  101021009  ...         633         620
# 11         10102  Queanbeyan  101021010  ...         323         297
# 12         10102  Queanbeyan  101021012  ...         600         508
# ...          ...         ...        ...  ...         ...         ...
# 51458        NaN         NaN        NaN  ...         NaN         NaN
# 51459        NaN         NaN        NaN  ...         NaN         NaN
# 51460        NaN         NaN        NaN  ...         NaN         NaN
# 51461        NaN         NaN        NaN  ...         NaN         NaN
# 51462        NaN         NaN        NaN  ...         NaN         NaN
#
#       Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27  \
# 8             233         197         125         108          79          57
# 9             491         300         223         201         144          64
# 10            520         444         384         394         320         214
# 11            199         152          97          94          82          54
# 12            294         224         159         105          70          29
# ...           ...         ...         ...         ...         ...         ...
# 51458         NaN         NaN         NaN         NaN         NaN         NaN
# 51459         NaN         NaN         NaN         NaN         NaN         NaN
# 51460         NaN         NaN         NaN         NaN         NaN         NaN
# 51461         NaN         NaN         NaN         NaN         NaN         NaN
# 51462         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 28 Unnamed: 29
# 8              37        2760
# 9              32        9129
# 10            226        9717
# 11             20        3925
# 12             24        9425
# ...           ...         ...
# 51458         NaN         NaN
# 51459         NaN         NaN
# 51460         NaN         NaN
# 51461         NaN         NaN
# 51462         NaN         NaN
#
# [51455 rows x 30 columns]

# %%
population=pd.read_csv('../data/raw/population_2.csv',header=0,names=['Year','S/T code','S/T name', 'GCCSA code', 'GCCSA name', \
                     'SA4 code', 'SA4 name', 'SA3 code', 'SA3 name', 'SA2 code', \
                     'SA2 name', '0-4','5-9', '10-14','15-19', '20-24','25-29',\
                    '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74',\
                    '75-79','80-84','85 and over', 'total persons'])
VIC_population = population.loc[population['S/T name']=='Victoria']
# Out:
# /Users/zhangwenwen/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
select_population = VIC_population.loc[:, ['Year','S/T name', 'SA2 name', '0-4','5-9', '10-14','15-19', '20-24','25-29',\
                    '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74',\
                    '75-79','80-84','85 and over', 'total persons']]

# %%
pop_18to21 = select_population.loc[(select_population['Year'] == '2018') | (select_population['Year']== '2019') | (select_population['Year']=='2020') | (select_population['Year']=='2021')] 
pop_18to21
# Out:
#        Year  S/T name             SA2 name     0-4     5-9   10-14   15-19  \
# 42300  2018  Victoria            Alfredton  1068.0  1109.0  1145.0  1102.0
# 42301  2018  Victoria             Ballarat   577.0   694.0   729.0   868.0
# 42302  2018  Victoria            Buninyong   431.0   585.0   550.0   582.0
# 42303  2018  Victoria            Delacombe   620.0   557.0   537.0   565.0
# 42304  2018  Victoria        Smythes Creek   232.0   311.0   366.0   326.0
# ...     ...       ...                  ...     ...     ...     ...     ...
# 50167  2021  Victoria                Otway   151.0   168.0   200.0   168.0
# 50168  2021  Victoria         Moyne - East   426.0   470.0   508.0   441.0
# 50169  2021  Victoria         Moyne - West   516.0   611.0   729.0   588.0
# 50170  2021  Victoria  Warrnambool - North  1259.0  1434.0  1598.0  1424.0
# 50171  2021  Victoria  Warrnambool - South   641.0   695.0   728.0   713.0
#
#         20-24   25-29   30-34  ...   45-49   50-54   55-59   60-64   65-69  \
# 42300   891.0   866.0   927.0  ...   913.0   760.0   716.0   616.0   519.0
# 42301   852.0   757.0   674.0  ...   843.0   786.0   845.0   751.0   712.0
# 42302   607.0   287.0   349.0  ...   516.0   448.0   530.0   471.0   449.0
# 42303   682.0   757.0   615.0  ...   477.0   406.0   462.0   395.0   362.0
# 42304   222.0   140.0   200.0  ...   341.0   314.0   305.0   261.0   211.0
# ...       ...     ...     ...  ...     ...     ...     ...     ...     ...
# 50167   109.0   157.0   209.0  ...   264.0   303.0   363.0   422.0   404.0
# 50168   330.0   351.0   437.0  ...   444.0   477.0   555.0   526.0   475.0
# 50169   389.0   424.0   506.0  ...   618.0   675.0   735.0   731.0   781.0
# 50170  1216.0  1463.0  1436.0  ...  1374.0  1435.0  1444.0  1404.0  1245.0
# 50171   673.0   892.0   832.0  ...   805.0   855.0   838.0   913.0   885.0
#
#         70-74  75-79  80-84  85 and over  total persons
# 42300   447.0  303.0  166.0        141.0        13520.0
# 42301   612.0  473.0  319.0        373.0        12237.0
# 42302   313.0  179.0  109.0         80.0         7413.0
# 42303   308.0  188.0  166.0        155.0         8174.0
# 42304   163.0   64.0   44.0         24.0         4040.0
# ...       ...    ...    ...          ...            ...
# 50167   311.0  182.0  103.0         71.0         3978.0
# 50168   339.0  210.0  153.0        113.0         6989.0
# 50169   671.0  420.0  228.0        252.0         9963.0
# 50170  1150.0  843.0  543.0        504.0        22462.0
# 50171   760.0  536.0  391.0        540.0        13292.0
#
# [2088 rows x 22 columns]

# %%
postcode_SA2 = pd.read_csv('../data/raw/postcode_info.csv')
postcode_SA2
# Out:
#       Unnamed: 0     ID  Postcode        Locality State   Longitude  \
# 0              0   4746      3000       MELBOURNE   VIC  144.956776
# 1              1   4747      3001       MELBOURNE   VIC  144.956776
# 2              2   4748      3002  EAST MELBOURNE   VIC  144.982207
# 3              3   4749      3003  WEST MELBOURNE   VIC  144.949592
# 4              4   4750      3004       MELBOURNE   VIC  144.970161
# ...          ...    ...       ...             ...   ...         ...
# 3529        3529  11311      8111       MELBOURNE   VIC  144.970161
# 3530        3530  11312      8120       MELBOURNE   VIC  144.970161
# 3531        3531  11313      8205       MELBOURNE   VIC  144.970161
# 3532        3532  11331      8785       DANDENONG   VIC  145.208504
# 3533        3533  23878      9999      NORTH POLE   VIC  144.956776
#
#        Latitude           Category               Type      SA3  ... MMM 2015  \
# 0    -37.817403      Delivery Area      Delivery Area  20604.0  ...      1.0
# 1    -37.817403  Post Office Boxes  Post Office Boxes  20605.0  ...      1.0
# 2    -37.818517      Delivery Area      Delivery Area  20604.0  ...      1.0
# 3    -37.810871      Delivery Area      Delivery Area  20604.0  ...      1.0
# 4    -37.844246      Delivery Area      Delivery Area  20605.0  ...      1.0
# ...         ...                ...                ...      ...  ...      ...
# 3529 -37.844246                LVR                LVR  20605.0  ...      1.0
# 3530 -37.844246                LVR                LVR  20605.0  ...      1.0
# 3531 -37.844246                LVR                LVR  20605.0  ...      1.0
# 3532 -38.016114  Post Office Boxes  Post Office Boxes  21204.0  ...      1.0
# 3533 -37.817403      Delivery Area      Delivery Area  20604.0  ...      1.0
#
#       MMM 2019        CED     Altitude Charge Zone  PHN Code  \
# 0          1.0  Melbourne    15.244751          V1    PHN201
# 1          1.0  Melbourne    15.244751          V1    PHN203
# 2          1.0  Melbourne    14.315022          V1    PHN201
# 3          1.0  Melbourne    15.316063          V1    PHN201
# 4          1.0  Macnamara -3492.000000          V1    PHN203
# ...        ...        ...          ...         ...       ...
# 3529       1.0        NaN          NaN          V1    PHN203
# 3530       1.0        NaN          NaN          V1    PHN203
# 3531       1.0        NaN          NaN          V1    PHN203
# 3532       1.0        NaN    15.138582          V1    PHN203
# 3533       1.0  Melbourne    15.244751         NaN       NaN
#
#                      PHN Name     LGA Region   Electorate   Electorate Rating
# 0     North Western Melbourne      Melbourne    Melbourne  Inner Metropolitan
# 1                         NaN  Moonee Valley  Maribyrnong                 NaN
# 2     North Western Melbourne          Yarra    Melbourne  Inner Metropolitan
# 3     North Western Melbourne      Melbourne    Melbourne  Inner Metropolitan
# 4     South Eastern Melbourne          Yarra    Macnamara  Inner Metropolitan
# ...                       ...            ...          ...                 ...
# 3529                      NaN          Yarra    Macnamara                 NaN
# 3530                      NaN          Yarra    Macnamara                 NaN
# 3531                      NaN          Yarra    Macnamara                 NaN
# 3532                      NaN         Monash       Isaacs                 NaN
# 3533                      NaN          Yarra    Macnamara                 NaN
#
# [3534 rows x 33 columns]

# %%
attribute = postcode_SA2.loc[:,['Postcode','Longitude','Latitude','SA2 NAME 2016']]
drop_dup = attribute.drop_duplicates(subset=['Postcode'])
drop_dup = drop_dup.drop_duplicates(subset=['Longitude','Latitude'])
rename = drop_dup.rename(columns={'SA2 NAME 2016':'SA2 name'})

# %%
rename
# Out:
#       Postcode   Longitude   Latitude        SA2 name
# 0         3000  144.956776 -37.817403       Melbourne
# 2         3002  144.982207 -37.818517  East Melbourne
# 3         3003  144.949592 -37.810871  West Melbourne
# 4         3004  144.970161 -37.844246       Southbank
# 7         3005  144.950858 -37.824608       Docklands
# ...        ...         ...        ...             ...
# 3512      8004  145.468994 -36.558800     Albert Park
# 3514      8006  144.959306 -37.809701       Melbourne
# 3517      8009  144.964531 -37.817201       Melbourne
# 3518      8010  146.293728 -38.185857          Romsey
# 3519      8011  144.961746 -37.811314       Melbourne
#
# [724 rows x 4 columns]

# %%
merge_data = pd.DataFrame(pd.merge(rename, pop_18to21, on='SA2 name', how='inner'))

# %%
merge_data.to_csv('../data/curated/population.csv')

# %%
merge_data
# Out:
#       Postcode   Longitude   Latitude               SA2 name  Year  S/T name  \
# 0         3002  144.982207 -37.818517         East Melbourne  2018  Victoria
# 1         3002  144.982207 -37.818517         East Melbourne  2019  Victoria
# 2         3002  144.982207 -37.818517         East Melbourne  2020  Victoria
# 3         3002  144.982207 -37.818517         East Melbourne  2021  Victoria
# 4         3005  144.950858 -37.824608              Docklands  2018  Victoria
# ...        ...         ...        ...                    ...   ...       ...
# 2363      3995  145.630713 -38.578071  Wonthaggi - Inverloch  2021  Victoria
# 2364      3996  145.745609 -38.629561  Wonthaggi - Inverloch  2018  Victoria
# 2365      3996  145.745609 -38.629561  Wonthaggi - Inverloch  2019  Victoria
# 2366      3996  145.745609 -38.629561  Wonthaggi - Inverloch  2020  Victoria
# 2367      3996  145.745609 -38.629561  Wonthaggi - Inverloch  2021  Victoria
#
#          0-4     5-9   10-14   15-19  ...   45-49   50-54   55-59   60-64  \
# 0      224.0    97.0    80.0   108.0  ...   300.0   290.0   349.0   342.0
# 1      218.0   103.0    79.0   114.0  ...   279.0   291.0   356.0   346.0
# 2      189.0   104.0    85.0   113.0  ...   268.0   304.0   351.0   351.0
# 3      121.0    97.0    90.0    97.0  ...   250.0   305.0   317.0   352.0
# 4      772.0   263.0   159.0   463.0  ...   763.0   703.0   635.0   510.0
# ...      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 2363  1267.0  1385.0  1466.0  1230.0  ...  1462.0  1693.0  1941.0  2287.0
# 2364  1212.0  1337.0  1299.0  1175.0  ...  1482.0  1527.0  1765.0  1941.0
# 2365  1220.0  1354.0  1324.0  1212.0  ...  1458.0  1544.0  1835.0  2008.0
# 2366  1213.0  1393.0  1375.0  1203.0  ...  1437.0  1589.0  1904.0  2112.0
# 2367  1267.0  1385.0  1466.0  1230.0  ...  1462.0  1693.0  1941.0  2287.0
#
#        65-69   70-74   75-79  80-84  85 and over  total persons
# 0      340.0   276.0   146.0   85.0        139.0         5409.0
# 1      354.0   289.0   161.0   95.0        128.0         5413.0
# 2      363.0   312.0   194.0   94.0        123.0         5378.0
# 3      324.0   318.0   208.0   96.0        116.0         4962.0
# 4      373.0   274.0   117.0   62.0         25.0        15439.0
# ...      ...     ...     ...    ...          ...            ...
# 2363  2423.0  2147.0  1482.0  909.0        799.0        26723.0
# 2364  1988.0  1815.0  1206.0  777.0        771.0        23966.0
# 2365  2091.0  1906.0  1248.0  835.0        783.0        24739.0
# 2366  2244.0  2026.0  1346.0  876.0        772.0        25631.0
# 2367  2423.0  2147.0  1482.0  909.0        799.0        26723.0
#
# [2368 rows x 25 columns]
