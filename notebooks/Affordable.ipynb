# %%
import os
import pandas as pd
import numpy as np
import pandas as pd

# %%
Yearly_income=pd.read_csv('../data/curated/VIC_yearly_income_poa.csv')

# %%
Yearly_income
# Out:
#      Unnamed: 0  Postcode               SA2 name  Median income in 2014-15  \
# 0             0      3000              Melbourne                     32697
# 1             1      3001              Melbourne                     32697
# 2             2      8001              Melbourne                     32697
# 3             3      8003              Melbourne                     32697
# 4             4      8006              Melbourne                     32697
# ..          ...       ...                    ...                       ...
# 711         711      3991  Wonthaggi - Inverloch                     36316
# 712         712      3992  Wonthaggi - Inverloch                     36316
# 713         713      3995  Wonthaggi - Inverloch                     36316
# 714         714      3996  Wonthaggi - Inverloch                     36316
# 715         715      8008     South Yarra - West                     66468
#
#      Median income in 2015-16  Median income in 2016-17  \
# 0                       31242                     28068
# 1                       31242                     28068
# 2                       31242                     28068
# 3                       31242                     28068
# 4                       31242                     28068
# ..                        ...                       ...
# 711                     36159                     36496
# 712                     36159                     36496
# 713                     36159                     36496
# 714                     36159                     36496
# 715                     65975                     65330
#
#      Median income in 2017-18  Median income in 2018-19  \
# 0                       28806                     30024
# 1                       28806                     30024
# 2                       28806                     30024
# 3                       28806                     30024
# 4                       28806                     30024
# ..                        ...                       ...
# 711                     38060                     39884
# 712                     38060                     39884
# 713                     38060                     39884
# 714                     38060                     39884
# 715                     68512                     70451
#
#      Median income in 2019-2020  Median income in 2020-2021  \
# 0                      29442.15                    28871.58
# 1                      29442.15                    28871.58
# 2                      29442.15                    28871.58
# 3                      29442.15                    28871.58
# 4                      29442.15                    28871.58
# ..                          ...                         ...
# 711                    40838.97                    41816.81
# 712                    40838.97                    41816.81
# 713                    40838.97                    41816.81
# 714                    40838.97                    41816.81
# 715                    71504.50                    72573.75
#
#      Median income in 2021-2022  Median income in 2022-2023  \
# 0                      28312.07                    27763.40
# 1                      28312.07                    27763.40
# 2                      28312.07                    27763.40
# 3                      28312.07                    27763.40
# 4                      28312.07                    27763.40
# ..                          ...                         ...
# 711                    42818.06                    43843.29
# 712                    42818.06                    43843.29
# 713                    42818.06                    43843.29
# 714                    42818.06                    43843.29
# 715                    73658.99                    74760.46
#
#      Median income in 2023-2024  Median income in 2024-2025  \
# 0                      27225.36                    26697.75
# 1                      27225.36                    26697.75
# 2                      27225.36                    26697.75
# 3                      27225.36                    26697.75
# 4                      27225.36                    26697.75
# ..                          ...                         ...
# 711                    44893.06                    45967.97
# 712                    44893.06                    45967.97
# 713                    44893.06                    45967.97
# 714                    44893.06                    45967.97
# 715                    75878.40                    77013.06
#
#      Median income in 2025-2026
# 0                      26180.37
# 1                      26180.37
# 2                      26180.37
# 3                      26180.37
# 4                      26180.37
# ..                          ...
# 711                    47068.62
# 712                    47068.62
# 713                    47068.62
# 714                    47068.62
# 715                    78164.69
#
# [716 rows x 15 columns]

# %%
Yearly_income_poa = Yearly_income.iloc[:,[1,8]]

# %%
Yearly_income_poa
# Out:
#      Postcode  Median income in 2019-2020
# 0        3000                    29442.15
# 1        3001                    29442.15
# 2        8001                    29442.15
# 3        8003                    29442.15
# 4        8006                    29442.15
# ..        ...                         ...
# 711      3991                    40838.97
# 712      3992                    40838.97
# 713      3995                    40838.97
# 714      3996                    40838.97
# 715      8008                    71504.50
#
# [716 rows x 2 columns]

# %%
External_rent=pd.read_excel('../data/raw/external_rent.xlsx',sheet_name='All Properties')
External_rent = External_rent.iloc[3:,[1,-1]]
External_rent = External_rent.dropna(axis='rows',how = 'all')

# %%
External_rent = External_rent.rename(columns={'Unnamed: 177':'Median rent price in 2021','Unnamed: 1':'LGA'})

# %%
External_rent['Median Yearly rent price in 2021'] = External_rent['Median rent price in 2021']*52

# %%
External_rent
# Out:
#                 LGA Median rent price in 2021 Median Yearly rent price in 2021
# 3       Colac-Otway                       335                            17420
# 4       Corangamite                       315                            16380
# 5           Glenelg                       330                            17160
# 6   Greater Geelong                       400                            20800
# 7             Moyne                       350                            18200
# ..              ...                       ...                              ...
# 89      Group Total                       400                            20800
# 90         Victoria                       390                            20280
# 92            Metro                       395                            20540
# 93        Non-Metro                       350                            18200
# 94         Victoria                       390                            20280
#
# [91 rows x 3 columns]

# %%
postcode_LGA = pd.read_csv('../data/raw/postcode_info.csv')
attribute = postcode_LGA.loc[:,['Postcode','LGA Region']]
drop_dup = attribute.drop_duplicates(subset=['Postcode'])
rename = drop_dup.rename(columns={'LGA Region':'LGA'})

# %%
External_rent_poa = pd.DataFrame(pd.merge(rename,External_rent, on='LGA', how='inner'))
External_rent_poa.dropna(axis='rows')
# Out:
#      Postcode         LGA Median rent price in 2021  \
# 0        3000   Melbourne                       370
# 1        3003   Melbourne                       370
# 2        3005   Melbourne                       370
# 3        3008   Melbourne                       370
# 4        3010   Melbourne                       370
# ..        ...         ...                       ...
# 714      3922  Bass Coast                       350
# 715      3923  Bass Coast                       350
# 716      3925  Bass Coast                       350
# 717      3991  Bass Coast                       350
# 718      3992  Bass Coast                       350
#
#     Median Yearly rent price in 2021
# 0                              19240
# 1                              19240
# 2                              19240
# 3                              19240
# 4                              19240
# ..                               ...
# 714                            18200
# 715                            18200
# 716                            18200
# 717                            18200
# 718                            18200
#
# [719 rows x 4 columns]

# %%
External_rent_poa = External_rent_poa.iloc[:,[0,3]]
External_rent_poa
# Out:
#      Postcode Median Yearly rent price in 2021
# 0        3000                            19240
# 1        3003                            19240
# 2        3005                            19240
# 3        3008                            19240
# 4        3010                            19240
# ..        ...                              ...
# 714      3922                            18200
# 715      3923                            18200
# 716      3925                            18200
# 717      3991                            18200
# 718      3992                            18200
#
# [719 rows x 2 columns]

# %%
rent_income = pd.DataFrame(pd.merge(External_rent_poa,Yearly_income_poa, on='Postcode', how='inner'))

# %%
rent_income
# Out:
#      Postcode Median Yearly rent price in 2021  Median income in 2019-2020
# 0        3000                            19240                    29442.15
# 1        3005                            19240                    55302.31
# 2        3008                            19240                    55302.31
# 3        3010                            19240                    51062.54
# 4        3013                            19240                    72148.85
# ..        ...                              ...                         ...
# 683      3922                            18200                    39317.19
# 684      3923                            18200                    39317.19
# 685      3925                            18200                    39317.19
# 686      3991                            18200                    40838.97
# 687      3992                            18200                    40838.97
#
# [688 rows x 3 columns]

# %%
rent_income['affordable index'] = rent_income['Median income in 2019-2020']/rent_income['Median Yearly rent price in 2021']
rent_income
# Out:
#      Postcode Median Yearly rent price in 2021  Median income in 2019-2020  \
# 0        3000                            19240                    29442.15
# 1        3005                            19240                    55302.31
# 2        3008                            19240                    55302.31
# 3        3010                            19240                    51062.54
# 4        3013                            19240                    72148.85
# ..        ...                              ...                         ...
# 683      3922                            18200                    39317.19
# 684      3923                            18200                    39317.19
# 685      3925                            18200                    39317.19
# 686      3991                            18200                    40838.97
# 687      3992                            18200                    40838.97
#
#     affordable index
# 0           1.530257
# 1            2.87434
# 2            2.87434
# 3           2.653978
# 4            3.74994
# ..               ...
# 683         2.160285
# 684         2.160285
# 685         2.160285
# 686         2.243899
# 687         2.243899
#
# [688 rows x 4 columns]

# %%
top_index = rent_income.sort_values(by='affordable index', ascending=False)

# %%
top_index.iloc[40:60,:]
# Out:
#      Postcode Median Yearly rent price in 2021  Median income in 2019-2020  \
# 400      3374                            12480                    48221.86
# 344      3407                            12376                    47760.43
# 338      3315                            12376                    47760.43
# 478      3529                            11336                    43695.65
# 477      3527                            11336                    43695.65
# 487      3570                            11336                    43230.42
# 479      3537                            11336                    43230.42
# 474      3516                            11336                    43230.42
# 491      3575                            11336                    43230.42
# 490      3573                            11336                    43230.42
# 476      3520                            11336                    43230.42
# 475      3517                            11336                    43230.42
# 488      3571                            11336                    43230.42
# 472      3506                            11336                    42834.16
# 5        3015                            19240                    72539.97
# 4        3013                            19240                    72148.85
# 61       3207                            21320                    78310.79
# 440      3483                            11960                    43695.65
# 480      3540                            11336                    40930.04
# 485      3567                            11336                    40930.04
#
#     affordable index
# 400         3.863931
# 344         3.859117
# 338         3.859117
# 478         3.854592
# 477         3.854592
# 487         3.813552
# 479         3.813552
# 474         3.813552
# 491         3.813552
# 490         3.813552
# 476         3.813552
# 475         3.813552
# 488         3.813552
# 472         3.778596
# 5           3.770269
# 4            3.74994
# 61          3.673114
# 440         3.653482
# 480         3.610625
# 485         3.610625
