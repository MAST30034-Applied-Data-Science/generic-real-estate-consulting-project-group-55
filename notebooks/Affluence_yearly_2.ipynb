# %%
import os
import pandas as pd
import numpy as np

# %%
Total_income=pd.read_excel('../data/raw/Total_income.xlsx',sheet_name='Table 1.4')
Total_income = Total_income.iloc[6:2302,0:27]
income_drop = Total_income.dropna(axis='columns',how = 'all')
income_drop.to_csv('../data/raw/Total_income_2.csv', encoding='utf-8')

# %%
income_drop
# Out:
#                  Australian Bureau of Statistics        Unnamed: 1  \
# 6                                     Australia                NaN
# 7                                New South Wales               NaN
# 8                                      101021007         Braidwood
# 9                                      101021008           Karabar
# 10                                     101021009        Queanbeyan
# ...                                          ...               ...
# 2297                                   801101136   Denman Prospect
# 2298                                   801101137          Molonglo
# 2299                                   801101138  Molonglo - North
# 2300                                   801101139            Wright
# 2301                                   801111140  ACT - South West
#
#       Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 6     13102895.0  13358252.0  13678024.0  14069082.0  14425037.0        42.0
# 7      4091347.0   4191542.0   4344997.0   4466941.0   4569650.0        42.0
# 8         2133.0      2153.0      2262.0      2315.0      2361.0        50.0
# 9         4866.0      4937.0      4988.0      5059.0      5100.0        43.0
# 10        6194.0      6419.0      6486.0      6595.0      6697.0        40.0
# ...          ...         ...         ...         ...         ...         ...
# 2297         NaN         NaN        90.0       181.0       416.0         NaN
# 2298         NaN         NaN         NaN         NaN         NaN         NaN
# 2299         NaN         NaN         NaN         NaN         NaN         NaN
# 2300      1109.0      1744.0      2028.0      2071.0      2121.0        35.0
# 2301       349.0       289.0       347.0       364.0       355.0        40.0
#
#       Unnamed: 8  Unnamed: 9  ...  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 6           42.0        42.0  ...      46854.0      47692.0        48360
# 7           42.0        42.0  ...      46879.0      48085.0        48700
# 8           50.0        50.0  ...      38093.0      39716.0        41288
# 9           42.0        42.0  ...      54942.0      55870.0        57880
# 10          39.0        39.0  ...      54716.0      54999.0        55376
# ...          ...         ...  ...          ...          ...          ...
# 2297         NaN        38.0  ...          NaN          NaN        84968
# 2298         NaN         NaN  ...          NaN          NaN          NaN
# 2299         NaN         NaN  ...          NaN          NaN          NaN
# 2300        33.0        33.0  ...      74718.0      75496.0        74670
# 2301        39.0        39.0  ...      55294.0      62592.0        55384
#
#       Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 6         49805.0      51389.0      61036.0      61975.0      62594.0
# 7         50153.0      51818.0      62798.0      64493.0      65196.0
# 8         42003.0      41593.0      47741.0      51074.0      51090.0
# 9         59295.0      61777.0      59548.0      61093.0      62535.0
# 10        57848.0      60119.0      59310.0      60764.0      60958.0
# ...           ...          ...          ...          ...          ...
# 2297      91138.0      90337.0          NaN          NaN      93743.0
# 2298          NaN          NaN          NaN          NaN          NaN
# 2299          NaN          NaN          NaN          NaN          NaN
# 2300      76754.0      79150.0      77432.0      79709.0      79610.0
# 2301      61096.0      64227.0      62505.0      72858.0      70503.0
#
#       Unnamed: 25 Unnamed: 26
# 6         64246.0     65953.0
# 7         67200.0     68816.0
# 8         51594.0     51149.0
# 9         63790.0     66335.0
# 10        62863.0     65874.0
# ...           ...         ...
# 2297      93812.0     98692.0
# 2298          NaN         NaN
# 2299          NaN         NaN
# 2300      82688.0     86007.0
# 2301      67445.0     73435.0
#
# [2296 rows x 27 columns]

# %%
salary_yearly=pd.read_csv('../data/raw/Total_income_2.csv',header=0,names=['SA2','SA2 name', 'Number of earners in 2014-15', 'Number of earners in 2015-16',\
    'Number of earners in 2016-17', 'Number of earners in 2017-18', 'Number of earners in 2018-19', 'Median age of earners in 2014-15',\
        'Median age of earners in 2015-16', 'Median age of earners in 2016-17','Median age of earners in 2017-18', 'Median age of earners in 2018-19',\
            'Total income in 2014-15', 'Total income in 2015-16','Total income in 2016-17', 'Total income in 2017-18','Total income in 2018-19',\
                'Median income in 2014-15','Median income in 2015-16','Median income in 2016-17','Median income in 2017-18','Median income in 2018-19',\
                    'Mean income in 2014-15','Mean income in 2015-16','Mean income in 2016-17','Mean income in 2017-18','Mean income in 2018-19'])
VIC_total = salary_yearly.loc[salary_yearly['SA2']=='Victoria']
QUS_total = salary_yearly.loc[salary_yearly['SA2']=='Queensland']

# %%
VIC_total
# Out:
#           SA2 SA2 name  Number of earners in 2014-15  \
# 584  Victoria      NaN                     3260682.0
#
#      Number of earners in 2015-16  Number of earners in 2016-17  \
# 584                     3352403.0                     3474938.0
#
#      Number of earners in 2017-18  Number of earners in 2018-19  \
# 584                     3603810.0                     3714224.0
#
#      Median age of earners in 2014-15  Median age of earners in 2015-16  \
# 584                              42.0                              42.0
#
#      Median age of earners in 2016-17  ...  Median income in 2014-15  \
# 584                              42.0  ...                   45930.0
#
#      Median income in 2015-16  Median income in 2016-17  \
# 584                   46984.0                     47709
#
#      Median income in 2017-18  Median income in 2018-19  \
# 584                   49266.0                   51027.0
#
#      Mean income in 2014-15  Mean income in 2015-16  Mean income in 2016-17  \
# 584                 59019.0                 60350.0                 61489.0
#
#      Mean income in 2017-18 Mean income in 2018-19
# 584                 63442.0                65366.0
#
# [1 rows x 27 columns]

# %%
QUS_total
# Out:
#              SA2 SA2 name Number of earners in 2014-15  \
# 1047  Queensland      NaN                      2592850
#
#      Number of earners in 2015-16 Number of earners in 2016-17  \
# 1047                      2623526                      2716386
#
#      Number of earners in 2017-18 Number of earners in 2018-19  \
# 1047                      2798990                      2876295
#
#      Median age of earners in 2014-15 Median age of earners in 2015-16  \
# 1047                               42                               42
#
#      Median age of earners in 2016-17  ... Median income in 2014-15  \
# 1047                               42  ...                    46052
#
#      Median income in 2015-16 Median income in 2016-17  \
# 1047                    46869                    47425
#
#      Median income in 2017-18 Median income in 2018-19 Mean income in 2014-15  \
# 1047                    48826                    50298                  58433
#
#      Mean income in 2015-16 Mean income in 2016-17 Mean income in 2017-18  \
# 1047                  59056                  59534                  60819
#
#      Mean income in 2018-19
# 1047                  62406
#
# [1 rows x 27 columns]

# %%
VIC_salary = salary_yearly.loc[584:1046]
VIC_salary
# Out:
#             SA2             SA2 name Number of earners in 2014-15  \
# 584    Victoria                  NaN                      3260682
# 585   201011001            Alfredton                         6225
# 586   201011002             Ballarat                         7289
# 587   201011003     Ballarat - North                        12503
# 588   201011004     Ballarat - South                        11347
# ...         ...                  ...                          ...
# 1042  217031476                Otway                         2225
# 1043  217041477         Moyne - East                         3890
# 1044  217041478         Moyne - West                         5650
# 1045  217041479  Warrnambool - North                        12185
# 1046  217041480  Warrnambool - South                         7431
#
#      Number of earners in 2015-16 Number of earners in 2016-17  \
# 584                       3352403                      3474938
# 585                          6718                         7124
# 586                          7400                         7470
# 587                         12516                        12889
# 588                         11529                        11905
# ...                           ...                          ...
# 1042                         2212                         2315
# 1043                         3833                         3879
# 1044                         5602                         5759
# 1045                        12346                        12694
# 1046                         7583                         7614
#
#      Number of earners in 2017-18 Number of earners in 2018-19  \
# 584                       3603810                      3714224
# 585                          7558                         7989
# 586                          7585                         7595
# 587                         13356                        13598
# 588                         12294                        12722
# ...                           ...                          ...
# 1042                         2297                         2360
# 1043                         3954                         4081
# 1044                         5765                         5852
# 1045                        12950                        13157
# 1046                         7734                         8052
#
#      Median age of earners in 2014-15 Median age of earners in 2015-16  \
# 584                                42                               42
# 585                                42                               42
# 586                                45                               46
# 587                                43                               43
# 588                                40                               39
# ...                               ...                              ...
# 1042                               52                               52
# 1043                               46                               46
# 1044                               47                               47
# 1045                               43                               43
# 1046                               44                               43
#
#      Median age of earners in 2016-17  ... Median income in 2014-15  \
# 584                                42  ...                    45930
# 585                                42  ...                    48532
# 586                                47  ...                    47894
# 587                                43  ...                    44494
# 588                                40  ...                    40846
# ...                               ...  ...                      ...
# 1042                               51  ...                    31322
# 1043                               46  ...                    40775
# 1044                               48  ...                    39961
# 1045                               43  ...                    42635
# 1046                               44  ...                    41641
#
#      Median income in 2015-16 Median income in 2016-17  \
# 584                     46984                    47709
# 585                     49385                    50845
# 586                     49564                    50413
# 587                     45816                    46561
# 588                     41544                    42531
# ...                       ...                      ...
# 1042                    33020                    32563
# 1043                    40053                    41244
# 1044                    41751                    42159
# 1045                    43536                    44772
# 1046                    42330                    43439
#
#      Median income in 2017-18 Median income in 2018-19 Mean income in 2014-15  \
# 584                     49266                    51027                  59019
# 585                     52448                    53932                  56374
# 586                     51736                    53688                  67217
# 587                     49211                    50593                  53017
# 588                     44293                    45828                  45473
# ...                       ...                      ...                    ...
# 1042                    33929                    36219                  40640
# 1043                    44000                    46071                  48627
# 1044                    43136                    45256                  48280
# 1045                    46945                    48855                  50513
# 1046                    45726                    47242                  50663
#
#      Mean income in 2015-16 Mean income in 2016-17 Mean income in 2017-18  \
# 584                   60350                  61489                  63442
# 585                   57747                  60026                  62315
# 586                   72754                  71895                  74671
# 587                   54660                  56067                  59786
# 588                   46143                  47676                  49041
# ...                     ...                    ...                    ...
# 1042                  42426                  44236                  44755
# 1043                  47031                  49104                  50652
# 1044                  50307                  51459                  52080
# 1045                  50939                  52090                  59812
# 1046                  50965                  53226                  54849
#
#      Mean income in 2018-19
# 584                   65366
# 585                   63668
# 586                   77876
# 587                   60367
# 588                   50778
# ...                     ...
# 1042                  46448
# 1043                  55573
# 1044                  55547
# 1045                  56099
# 1046                  58247
#
# [463 rows x 27 columns]

# %%
VIC_salary.dtypes
# Out:
# SA2                                 object
# SA2 name                            object
# Number of earners in 2014-15        object
# Number of earners in 2015-16        object
# Number of earners in 2016-17        object
# Number of earners in 2017-18        object
# Number of earners in 2018-19        object
# Median age of earners in 2014-15    object
# Median age of earners in 2015-16    object
# Median age of earners in 2016-17    object
# Median age of earners in 2017-18    object
# Median age of earners in 2018-19    object
# Total income in 2014-15             object
# Total income in 2015-16             object
# Total income in 2016-17             object
# Total income in 2017-18             object
# Total income in 2018-19             object
# Median income in 2014-15            object
# Median income in 2015-16            object
# Median income in 2016-17            object
# Median income in 2017-18            object
# Median income in 2018-19            object
# Mean income in 2014-15              object
# Mean income in 2015-16              object
# Mean income in 2016-17              object
# Mean income in 2017-18              object
# Mean income in 2018-19              object
# dtype: object

# %%
median_col = VIC_salary.columns.to_list()
median_col
# Out:
# ['SA2',
#  'SA2 name',
#  'Number of earners in 2014-15',
#  'Number of earners in 2015-16',
#  'Number of earners in 2016-17',
#  'Number of earners in 2017-18',
#  'Number of earners in 2018-19',
#  'Median age of earners in 2014-15',
#  'Median age of earners in 2015-16',
#  'Median age of earners in 2016-17',
#  'Median age of earners in 2017-18',
#  'Median age of earners in 2018-19',
#  'Total income in 2014-15',
#  'Total income in 2015-16',
#  'Total income in 2016-17',
#  'Total income in 2017-18',
#  'Total income in 2018-19',
#  'Median income in 2014-15',
#  'Median income in 2015-16',
#  'Median income in 2016-17',
#  'Median income in 2017-18',
#  'Median income in 2018-19',
#  'Mean income in 2014-15',
#  'Mean income in 2015-16',
#  'Mean income in 2016-17',
#  'Mean income in 2017-18',
#  'Mean income in 2018-19']

# %%
columns = []
for i in range(len(median_col)):
    if median_col[i].startswith("Median income"):
        if median_col[i] != "Median income in 2018-19":
            columns.append((median_col[i],median_col[i+1]))
columns
# Out:
# [('Median income in 2014-15', 'Median income in 2015-16'),
#  ('Median income in 2015-16', 'Median income in 2016-17'),
#  ('Median income in 2016-17', 'Median income in 2017-18'),
#  ('Median income in 2017-18', 'Median income in 2018-19')]

# %%
a = []

for i in VIC_salary["Median income in 2017-18"]:
        #print(i)
    a.append(i)

for j in range(80, 88):
    print(type(a[j]))
#a[80:88]
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
def avg_year(year1, year2):
    result = 0
    if year1!= "np" and year2!="np":
        year1 = int(year1)
        year2 = int(year2)
        if year1 != 0:
            result =  float(year2/year1)
        if year1 == 0:
            result = 0
    return result

# %%
df = pd.DataFrame()

for (col_1, col_2) in columns: 
    df[f'{col_1}' + f'{col_2}'] = VIC_salary.apply(lambda x: avg_year(x[f"{col_1}"], x[f'{col_2}']), axis=1)

df['Median Income growth rate'] = (df.sum(axis=1))/len(df.columns)
df
# Out:
#       Median income in 2014-15Median income in 2015-16  \
# 584                                           1.022948
# 585                                           1.017576
# 586                                           1.034869
# 587                                           1.029712
# 588                                           1.017089
# ...                                                ...
# 1042                                          1.054211
# 1043                                          0.982293
# 1044                                          1.044794
# 1045                                          1.021133
# 1046                                          1.016546
#
#       Median income in 2015-16Median income in 2016-17  \
# 584                                           1.015431
# 585                                           1.029564
# 586                                           1.017129
# 587                                           1.016261
# 588                                           1.023758
# ...                                                ...
# 1042                                          0.986160
# 1043                                          1.029736
# 1044                                          1.009772
# 1045                                          1.028390
# 1046                                          1.026199
#
#       Median income in 2016-17Median income in 2017-18  \
# 584                                           1.032635
# 585                                           1.031527
# 586                                           1.026243
# 587                                           1.056915
# 588                                           1.041429
# ...                                                ...
# 1042                                          1.041949
# 1043                                          1.066822
# 1044                                          1.023174
# 1045                                          1.048535
# 1046                                          1.052649
#
#       Median income in 2017-18Median income in 2018-19  \
# 584                                           1.035745
# 585                                           1.028295
# 586                                           1.037730
# 587                                           1.028083
# 588                                           1.034656
# ...                                                ...
# 1042                                          1.067494
# 1043                                          1.047068
# 1044                                          1.049147
# 1045                                          1.040686
# 1046                                          1.033154
#
#       Median Income growth rate
# 584                    1.026690
# 585                    1.026740
# 586                    1.028993
# 587                    1.032743
# 588                    1.029233
# ...                         ...
# 1042                   1.037454
# 1043                   1.031480
# 1044                   1.031722
# 1045                   1.034686
# 1046                   1.032137
#
# [463 rows x 5 columns]

# %%
df.dtypes
# Out:
# Median income in 2014-15Median income in 2015-16    float64
# Median income in 2015-16Median income in 2016-17    float64
# Median income in 2016-17Median income in 2017-18    float64
# Median income in 2017-18Median income in 2018-19    float64
# Median Income growth rate                           float64
# dtype: object

# %%
#VIC_salary = VIC_salary.replace("np",np.nan)

# %%
VIC_salary['Median Income growth rate'] = df['Median Income growth rate']

# %%
VIC_salary
# Out:
#             SA2             SA2 name Number of earners in 2014-15  \
# 584    Victoria                  NaN                      3260682
# 585   201011001            Alfredton                         6225
# 586   201011002             Ballarat                         7289
# 587   201011003     Ballarat - North                        12503
# 588   201011004     Ballarat - South                        11347
# ...         ...                  ...                          ...
# 1042  217031476                Otway                         2225
# 1043  217041477         Moyne - East                         3890
# 1044  217041478         Moyne - West                         5650
# 1045  217041479  Warrnambool - North                        12185
# 1046  217041480  Warrnambool - South                         7431
#
#      Number of earners in 2015-16 Number of earners in 2016-17  \
# 584                       3352403                      3474938
# 585                          6718                         7124
# 586                          7400                         7470
# 587                         12516                        12889
# 588                         11529                        11905
# ...                           ...                          ...
# 1042                         2212                         2315
# 1043                         3833                         3879
# 1044                         5602                         5759
# 1045                        12346                        12694
# 1046                         7583                         7614
#
#      Number of earners in 2017-18 Number of earners in 2018-19  \
# 584                       3603810                      3714224
# 585                          7558                         7989
# 586                          7585                         7595
# 587                         13356                        13598
# 588                         12294                        12722
# ...                           ...                          ...
# 1042                         2297                         2360
# 1043                         3954                         4081
# 1044                         5765                         5852
# 1045                        12950                        13157
# 1046                         7734                         8052
#
#      Median age of earners in 2014-15 Median age of earners in 2015-16  \
# 584                                42                               42
# 585                                42                               42
# 586                                45                               46
# 587                                43                               43
# 588                                40                               39
# ...                               ...                              ...
# 1042                               52                               52
# 1043                               46                               46
# 1044                               47                               47
# 1045                               43                               43
# 1046                               44                               43
#
#      Median age of earners in 2016-17  ... Median income in 2015-16  \
# 584                                42  ...                    46984
# 585                                42  ...                    49385
# 586                                47  ...                    49564
# 587                                43  ...                    45816
# 588                                40  ...                    41544
# ...                               ...  ...                      ...
# 1042                               51  ...                    33020
# 1043                               46  ...                    40053
# 1044                               48  ...                    41751
# 1045                               43  ...                    43536
# 1046                               44  ...                    42330
#
#      Median income in 2016-17 Median income in 2017-18  \
# 584                     47709                    49266
# 585                     50845                    52448
# 586                     50413                    51736
# 587                     46561                    49211
# 588                     42531                    44293
# ...                       ...                      ...
# 1042                    32563                    33929
# 1043                    41244                    44000
# 1044                    42159                    43136
# 1045                    44772                    46945
# 1046                    43439                    45726
#
#      Median income in 2018-19 Mean income in 2014-15 Mean income in 2015-16  \
# 584                     51027                  59019                  60350
# 585                     53932                  56374                  57747
# 586                     53688                  67217                  72754
# 587                     50593                  53017                  54660
# 588                     45828                  45473                  46143
# ...                       ...                    ...                    ...
# 1042                    36219                  40640                  42426
# 1043                    46071                  48627                  47031
# 1044                    45256                  48280                  50307
# 1045                    48855                  50513                  50939
# 1046                    47242                  50663                  50965
#
#      Mean income in 2016-17 Mean income in 2017-18 Mean income in 2018-19  \
# 584                   61489                  63442                  65366
# 585                   60026                  62315                  63668
# 586                   71895                  74671                  77876
# 587                   56067                  59786                  60367
# 588                   47676                  49041                  50778
# ...                     ...                    ...                    ...
# 1042                  44236                  44755                  46448
# 1043                  49104                  50652                  55573
# 1044                  51459                  52080                  55547
# 1045                  52090                  59812                  56099
# 1046                  53226                  54849                  58247
#
#      Median Income growth rate
# 584                   1.026690
# 585                   1.026740
# 586                   1.028993
# 587                   1.032743
# 588                   1.029233
# ...                        ...
# 1042                  1.037454
# 1043                  1.031480
# 1044                  1.031722
# 1045                  1.034686
# 1046                  1.032137
#
# [463 rows x 28 columns]

# %%
rate = list(df["Median Income growth rate"])
in18_19 = list(VIC_salary["Median income in 2018-19"])

# %%
in19_20 = []
in20_21 = []
in21_22 = []
in22_23 = []
in23_24 = []
in24_25 = []

for i in range(len(rate)):
    if rate[i] != "np" and in18_19[i] != "np":
        in19_20.append(round(float(rate[i]) * int(in18_19[i]),2))
        in20_21.append(round((rate[i]) * (in19_20[i]),2))
        in21_22.append(round((rate[i]) * (in20_21[i]),2))
        in22_23.append(round((rate[i]) * (in21_22[i]),2))
        in23_24.append(round((rate[i]) * (in22_23[i]),2))
        in24_25.append(round((rate[i]) * (in23_24[i]),2))
    else:
        in19_20.append("np")
        in20_21.append("np")
        in21_22.append("np")
        in22_23.append("np")
        in23_24.append("np")
        in24_25.append("np")

in24_25
# Out:
# [59763.4,
#  83746.84,
#  64648.86,
#  87552.03,
#  65460.65,
#  63939.65,
#  57169.2,
#  59127.32,
#  58034.24,
#  80685.91,
#  64813.75,
#  60104.18,
#  58676.56,
#  65369.39,
#  56450.3,
#  49760.57,
#  52700.07,
#  52771.32,
#  53095.95,
#  67349.42,
#  59832.72,
#  56004.87,
#  59108.12,
#  67913.09,
#  55706.53,
#  65229.9,
#  65178.18,
#  57986.84,
#  56104.01,
#  64486.0,
#  67699.83,
#  63228.26,
#  65515.88,
#  55000.12,
#  58552.52,
#  58027.55,
#  56579.51,
#  66930.62,
#  61707.11,
#  51271.91,
#  50718.77,
#  60625.21,
#  56139.08,
#  71959.98,
#  60505.96,
#  75364.62,
#  65975.89,
#  52524.15,
#  59243.07,
#  79416.4,
#  65191.13,
#  61204.88,
#  57013.74,
#  46019.79,
#  47850.58,
#  53447.67,
#  55141.88,
#  66347.25,
#  45316.9,
#  50884.62,
#  48886.83,
#  55672.58,
#  57654.44,
#  53282.95,
#  53097.67,
#  50994.85,
#  45872.93,
#  46551.12,
#  48978.66,
#  50697.94,
#  49246.31,
#  49575.1,
#  51931.43,
#  59294.0,
#  52746.85,
#  49957.1,
#  54768.6,
#  56748.31,
#  55182.76,
#  55458.47,
#  60869.57,
#  52605.3,
#  58335.78,
#  49128.56,
#  56597.36,
#  41775.93,
#  45159.43,
#  55487.07,
#  54582.28,
#  59946.01,
#  57115.26]

# %%
VIC_salary["Median income in 2019-2020"]= in19_20

VIC_salary["Median income in 2020-2021"]= in20_21
VIC_salary["Median income in 2021-2022"]= in21_22
VIC_salary["Median income in 2022-2023"]= in22_23
VIC_salary["Median income in 2023-2024"]= in23_24
VIC_salary["Median income in 2024-2025"]= in24_25

#VIC_salary.to_csv('../data/curated/population_SA2.csv')
# Out:
# /tmp/ipykernel_11307/3622842207.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_salary["Median income in 2019-2020"]= in19_20
# /tmp/ipykernel_11307/3622842207.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_salary["Median income in 2020-2021"]= in20_21
# /tmp/ipykernel_11307/3622842207.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_salary["Median income in 2021-2022"]= in21_22
# /tmp/ipykernel_11307/3622842207.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_salary["Median income in 2022-2023"]= in22_23
# /tmp/ipykernel_11307/3622842207.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_salary["Median income in 2023-2024"]= in23_24
# /tmp/ipykernel_11307/3622842207.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VIC_salary["Median income in 2024-2025"]= in24_25

# %%
VIC_salary
# Out:
#             SA2             SA2 name Number of earners in 2014-15  \
# 584    Victoria                  NaN                      3260682
# 585   201011001            Alfredton                         6225
# 586   201011002             Ballarat                         7289
# 587   201011003     Ballarat - North                        12503
# 588   201011004     Ballarat - South                        11347
# ...         ...                  ...                          ...
# 1042  217031476                Otway                         2225
# 1043  217041477         Moyne - East                         3890
# 1044  217041478         Moyne - West                         5650
# 1045  217041479  Warrnambool - North                        12185
# 1046  217041480  Warrnambool - South                         7431
#
#      Number of earners in 2015-16 Number of earners in 2016-17  \
# 584                       3352403                      3474938
